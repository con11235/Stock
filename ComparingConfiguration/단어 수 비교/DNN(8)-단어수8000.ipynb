# %%
# 사용할 데이터의 형태
data_type = '8'      # '1' : summarize X,개별 기사   '2' : summarize X,날짜별 기사
                    # '3' : summarize O,개별 기사   '4' : summarize O,날짜별 기사
normalized = 'done' # 'done' : 데이터 행별 normalize한 데이터     'not' : 데이터 행별 normalize 안한 데이터
erased_word = ''    # 제거된 단어 형태
num_word = '8000'   # 사용할 단어 수

# 돌려볼 모델의 구조
first_layer = 3000   # 모델의 첫 번째 레이어 수
second_layer = 1000  # 모델의 두 번째 레이어 수
ep = 60             # 모델의 에포크 수
ba = 1000            # 모델의 배치 사이즈

# %%
# 생성된 training, test의 x,y값을 pickle의 형태로 저장
import pickle
import os
path = os.getcwd()+'/pickles/'
if erased_word != '':
    erased_word = '_'+erased_word
with open(path+data_type+'train_x_'+str(num_word)+'_'+normalized+erased_word+'.pickle', 'rb') as f:
    train_x = pickle.load(f)
with open(path+data_type+'train_y_'+str(num_word)+'_'+normalized+erased_word+'.pickle', 'rb') as f:
    train_y = pickle.load(f)
with open(path+data_type+'train2_x_'+str(num_word)+'_'+normalized+erased_word+'.pickle', 'rb') as f:
    train2_x = pickle.load(f)
with open(path+data_type+'train2_y_'+str(num_word)+'_'+normalized+erased_word+'.pickle', 'rb') as f:
    train2_y = pickle.load(f)
with open(path+data_type+'test_x_'+str(num_word)+'_'+normalized+erased_word+'.pickle', 'rb') as f:
    test_x = pickle.load(f)
with open(path+data_type+'test_y_'+str(num_word)+'_'+normalized+erased_word+'.pickle', 'rb') as f:
    test_y = pickle.load(f)
with open(path+data_type+'test2_x_'+str(num_word)+'_'+normalized+erased_word+'.pickle', 'rb') as f:
    test2_x = pickle.load(f)
with open(path+data_type+'test2_y_'+str(num_word)+'_'+normalized+erased_word+'.pickle', 'rb') as f:
    test2_y = pickle.load(f)

# %%
# numpy 사용하여 float로 바꾸어주는 과정
import numpy as np
x_train = np.asarray(train_x).astype('float32')
y_train = np.asarray(train_y).astype('float32')
x_test = np.asarray(test_x).astype('float32')
y_test = np.asarray(test_y).astype('float32')

# %%
# DNN 학습 모델
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import optimizers
from tensorflow.keras import losses
from tensorflow.keras import metrics
#from tensorflow.keras.callbacks import EarlyStopping


#callbacks = [EarlyStopping(monitor='val_loss',patience = 20)]
model = models.Sequential()
n =len(x_train[0])
model.add(layers.Dense(first_layer,activation='relu'))#실제 쓸 단어갯수
model.add(layers.Dense(second_layer,activation='relu'))
model.add(layers.Dense(3,activation='softmax'))
model.compile(optimizer=optimizers.RMSprop(lr=0.001),loss = losses.categorical_crossentropy,metrics=[metrics.categorical_accuracy])

#hist = model.fit(x_train,y_train,epochs=ep,validation_data=(x_train2,y_train2),callbacks=callbacks,batch_size=ba, shuffle=True)
hist = model.fit(x_train,y_train,epochs=ep,validation_data=(x_test,y_test),batch_size=ba)
# Out:
# Epoch 1/60
# 10/10 [==============================] - 17s 2s/step - loss: 1.0911 - categorical_accuracy: 0.3744 - val_loss: 1.0873 - val_categorical_accuracy: 0.4134
# Epoch 2/60
# 10/10 [==============================] - 10s 951ms/step - loss: 1.0757 - categorical_accuracy: 0.4108 - val_loss: 1.0743 - val_categorical_accuracy: 0.4330
# Epoch 3/60
# 10/10 [==============================] - 9s 875ms/step - loss: 1.0642 - categorical_accuracy: 0.4357 - val_loss: 1.0800 - val_categorical_accuracy: 0.3882
# Epoch 4/60
# 10/10 [==============================] - 9s 868ms/step - loss: 1.0263 - categorical_accuracy: 0.4502 - val_loss: 1.0596 - val_categorical_accuracy: 0.4331
# Epoch 5/60
# 10/10 [==============================] - 9s 865ms/step - loss: 1.0081 - categorical_accuracy: 0.4847 - val_loss: 1.0439 - val_categorical_accuracy: 0.4527
# Epoch 6/60
# 10/10 [==============================] - 9s 905ms/step - loss: 0.9615 - categorical_accuracy: 0.5236 - val_loss: 1.0357 - val_categorical_accuracy: 0.4643
# Epoch 7/60
# 10/10 [==============================] - 11s 1s/step - loss: 0.9272 - categorical_accuracy: 0.5626 - val_loss: 1.1838 - val_categorical_accuracy: 0.4279
# Epoch 8/60
# 10/10 [==============================] - 10s 969ms/step - loss: 0.9282 - categorical_accuracy: 0.5496 - val_loss: 1.0357 - val_categorical_accuracy: 0.4692
# Epoch 9/60
# 10/10 [==============================] - 9s 903ms/step - loss: 0.8734 - categorical_accuracy: 0.5837 - val_loss: 1.0330 - val_categorical_accuracy: 0.4742
# Epoch 10/60
# 10/10 [==============================] - 9s 903ms/step - loss: 0.8499 - categorical_accuracy: 0.6122 - val_loss: 1.1002 - val_categorical_accuracy: 0.4655
# Epoch 11/60
# 10/10 [==============================] - 9s 882ms/step - loss: 0.8385 - categorical_accuracy: 0.6240 - val_loss: 1.0648 - val_categorical_accuracy: 0.4766
# Epoch 12/60
# 10/10 [==============================] - 9s 910ms/step - loss: 0.7665 - categorical_accuracy: 0.6659 - val_loss: 1.1106 - val_categorical_accuracy: 0.4630
# Epoch 13/60
# 10/10 [==============================] - 9s 911ms/step - loss: 0.7376 - categorical_accuracy: 0.6704 - val_loss: 1.1743 - val_categorical_accuracy: 0.4299
# Epoch 14/60
# 10/10 [==============================] - 9s 910ms/step - loss: 0.7153 - categorical_accuracy: 0.6886 - val_loss: 1.2764 - val_categorical_accuracy: 0.4399
# Epoch 15/60
# 10/10 [==============================] - 9s 898ms/step - loss: 0.6854 - categorical_accuracy: 0.7055 - val_loss: 1.1595 - val_categorical_accuracy: 0.4769
# Epoch 16/60
# 10/10 [==============================] - 9s 889ms/step - loss: 0.6638 - categorical_accuracy: 0.7162 - val_loss: 1.0894 - val_categorical_accuracy: 0.4813
# Epoch 17/60
# 10/10 [==============================] - 9s 889ms/step - loss: 0.6511 - categorical_accuracy: 0.7162 - val_loss: 1.1909 - val_categorical_accuracy: 0.4843
# Epoch 18/60
# 10/10 [==============================] - 9s 885ms/step - loss: 0.6063 - categorical_accuracy: 0.7464 - val_loss: 1.1549 - val_categorical_accuracy: 0.4823
# Epoch 19/60
# 10/10 [==============================] - 9s 882ms/step - loss: 0.5554 - categorical_accuracy: 0.7731 - val_loss: 1.4126 - val_categorical_accuracy: 0.4823
# Epoch 20/60
# 10/10 [==============================] - 9s 883ms/step - loss: 0.5672 - categorical_accuracy: 0.7680 - val_loss: 1.1435 - val_categorical_accuracy: 0.4832
# Epoch 21/60
# 10/10 [==============================] - 9s 876ms/step - loss: 0.5181 - categorical_accuracy: 0.7966 - val_loss: 1.3846 - val_categorical_accuracy: 0.4946
# Epoch 22/60
# 10/10 [==============================] - 9s 880ms/step - loss: 0.4805 - categorical_accuracy: 0.8063 - val_loss: 1.3856 - val_categorical_accuracy: 0.4389
# Epoch 23/60
# 10/10 [==============================] - 9s 890ms/step - loss: 0.4374 - categorical_accuracy: 0.8312 - val_loss: 1.3689 - val_categorical_accuracy: 0.4453
# Epoch 24/60
# 10/10 [==============================] - 9s 877ms/step - loss: 0.4391 - categorical_accuracy: 0.8331 - val_loss: 1.5610 - val_categorical_accuracy: 0.4943
# Epoch 25/60
# 10/10 [==============================] - 9s 869ms/step - loss: 0.3966 - categorical_accuracy: 0.8439 - val_loss: 1.9929 - val_categorical_accuracy: 0.4742
# Epoch 26/60
# 10/10 [==============================] - 9s 870ms/step - loss: 0.4425 - categorical_accuracy: 0.8256 - val_loss: 1.2281 - val_categorical_accuracy: 0.5013
# Epoch 27/60
# 10/10 [==============================] - 9s 876ms/step - loss: 0.3439 - categorical_accuracy: 0.8806 - val_loss: 1.2762 - val_categorical_accuracy: 0.5034
# Epoch 28/60
# 10/10 [==============================] - 9s 868ms/step - loss: 0.3468 - categorical_accuracy: 0.8672 - val_loss: 1.6521 - val_categorical_accuracy: 0.5025
# Epoch 29/60
# 10/10 [==============================] - 9s 866ms/step - loss: 0.3644 - categorical_accuracy: 0.8449 - val_loss: 1.3986 - val_categorical_accuracy: 0.4682
# Epoch 30/60
# 10/10 [==============================] - 9s 862ms/step - loss: 0.2198 - categorical_accuracy: 0.9287 - val_loss: 2.6309 - val_categorical_accuracy: 0.4247
# Epoch 31/60
# 10/10 [==============================] - 9s 857ms/step - loss: 0.3698 - categorical_accuracy: 0.8673 - val_loss: 1.5838 - val_categorical_accuracy: 0.5182
# Epoch 32/60
# 10/10 [==============================] - 9s 861ms/step - loss: 0.2618 - categorical_accuracy: 0.8989 - val_loss: 1.7606 - val_categorical_accuracy: 0.5077
# Epoch 33/60
# 10/10 [==============================] - 9s 859ms/step - loss: 0.2153 - categorical_accuracy: 0.9270 - val_loss: 1.6934 - val_categorical_accuracy: 0.5216
# Epoch 34/60
# 10/10 [==============================] - 9s 862ms/step - loss: 0.4448 - categorical_accuracy: 0.8447 - val_loss: 1.3457 - val_categorical_accuracy: 0.5202
# Epoch 35/60
# 10/10 [==============================] - 9s 862ms/step - loss: 0.1349 - categorical_accuracy: 0.9705 - val_loss: 1.6709 - val_categorical_accuracy: 0.5222
# Epoch 36/60
# 10/10 [==============================] - 9s 856ms/step - loss: 0.1682 - categorical_accuracy: 0.9407 - val_loss: 3.0986 - val_categorical_accuracy: 0.4224
# Epoch 37/60
# 10/10 [==============================] - 9s 857ms/step - loss: 0.3281 - categorical_accuracy: 0.8617 - val_loss: 1.6138 - val_categorical_accuracy: 0.5243
# Epoch 38/60
# 10/10 [==============================] - 9s 860ms/step - loss: 0.0934 - categorical_accuracy: 0.9749 - val_loss: 2.1435 - val_categorical_accuracy: 0.5002
# Epoch 39/60
# 10/10 [==============================] - 9s 859ms/step - loss: 0.5141 - categorical_accuracy: 0.8232 - val_loss: 1.6092 - val_categorical_accuracy: 0.5249
# Epoch 40/60
# 10/10 [==============================] - 9s 873ms/step - loss: 0.0920 - categorical_accuracy: 0.9771 - val_loss: 1.7862 - val_categorical_accuracy: 0.5222
# Epoch 41/60
# 10/10 [==============================] - 9s 912ms/step - loss: 0.2156 - categorical_accuracy: 0.9175 - val_loss: 1.7908 - val_categorical_accuracy: 0.4144
# Epoch 42/60
# 10/10 [==============================] - 9s 910ms/step - loss: 0.1537 - categorical_accuracy: 0.9459 - val_loss: 1.7953 - val_categorical_accuracy: 0.5243
# Epoch 43/60
# 10/10 [==============================] - 9s 916ms/step - loss: 0.0702 - categorical_accuracy: 0.9788 - val_loss: 2.0334 - val_categorical_accuracy: 0.5236
# Epoch 44/60
# 10/10 [==============================] - 9s 884ms/step - loss: 0.4745 - categorical_accuracy: 0.8403 - val_loss: 1.5852 - val_categorical_accuracy: 0.5320
# Epoch 45/60
# 10/10 [==============================] - 9s 879ms/step - loss: 0.0813 - categorical_accuracy: 0.9809 - val_loss: 1.8768 - val_categorical_accuracy: 0.5264
# Epoch 46/60
# 10/10 [==============================] - 9s 875ms/step - loss: 0.0657 - categorical_accuracy: 0.9788 - val_loss: 2.3621 - val_categorical_accuracy: 0.5120
# Epoch 47/60
# 10/10 [==============================] - 9s 895ms/step - loss: 0.2951 - categorical_accuracy: 0.8962 - val_loss: 1.6827 - val_categorical_accuracy: 0.5185
# Epoch 48/60
# 10/10 [==============================] - 9s 879ms/step - loss: 0.0621 - categorical_accuracy: 0.9820 - val_loss: 1.9774 - val_categorical_accuracy: 0.5261
# Epoch 49/60
# 10/10 [==============================] - 9s 892ms/step - loss: 0.3271 - categorical_accuracy: 0.8882 - val_loss: 1.7203 - val_categorical_accuracy: 0.4769
# Epoch 50/60
# 10/10 [==============================] - 9s 894ms/step - loss: 0.0720 - categorical_accuracy: 0.9794 - val_loss: 1.9118 - val_categorical_accuracy: 0.5249
# Epoch 51/60
# 10/10 [==============================] - 9s 943ms/step - loss: 0.0491 - categorical_accuracy: 0.9845 - val_loss: 2.0888 - val_categorical_accuracy: 0.5246
# Epoch 52/60
# 10/10 [==============================] - 9s 900ms/step - loss: 0.2657 - categorical_accuracy: 0.9170 - val_loss: 2.5598 - val_categorical_accuracy: 0.4678
# Epoch 53/60
# 10/10 [==============================] - 9s 894ms/step - loss: 0.1032 - categorical_accuracy: 0.9605 - val_loss: 1.9878 - val_categorical_accuracy: 0.5243
# Epoch 54/60
# 10/10 [==============================] - 9s 896ms/step - loss: 0.0439 - categorical_accuracy: 0.9853 - val_loss: 2.0923 - val_categorical_accuracy: 0.5222
# Epoch 55/60
# 10/10 [==============================] - 9s 912ms/step - loss: 0.4504 - categorical_accuracy: 0.8655 - val_loss: 3.1611 - val_categorical_accuracy: 0.4517
# Epoch 56/60
# 10/10 [==============================] - 9s 908ms/step - loss: 0.1045 - categorical_accuracy: 0.9635 - val_loss: 1.8709 - val_categorical_accuracy: 0.5258
# Epoch 57/60
# 10/10 [==============================] - 9s 909ms/step - loss: 0.0437 - categorical_accuracy: 0.9851 - val_loss: 2.0564 - val_categorical_accuracy: 0.5246
# Epoch 58/60
# 10/10 [==============================] - 9s 885ms/step - loss: 0.0392 - categorical_accuracy: 0.9854 - val_loss: 2.2645 - val_categorical_accuracy: 0.5231
# Epoch 59/60
# 10/10 [==============================] - 9s 882ms/step - loss: 0.1219 - categorical_accuracy: 0.9539 - val_loss: 3.5015 - val_categorical_accuracy: 0.4394
# Epoch 60/60
# 10/10 [==============================] - 9s 879ms/step - loss: 0.2074 - categorical_accuracy: 0.9340 - val_loss: 1.9621 - val_categorical_accuracy: 0.5269

# %%
# 모델의 예측값을 튜플로 반환하는 함수
def predict(x):
    data = np.expand_dims(np.asarray(x).astype('float32'),axis=0)
    result = model.predict(data)
    return tuple(result[0])

# %%
# 모든 날짜의 예측값들을 합치기 위한 튜플의 합 함수
def sum_tuple(a,b):
    return (a[0]+b[0],a[1]+b[1],a[2]+b[2])

# %%
# Test set에 대한 예측 및 예측 정확도의 계산
import re

#count = 0
#sum_dic = {}
#for data in train2_x:
#    result = predict(data[0])
#    if data[1] in sum_dic:
#        sum_dic[data[1]] = sum_tuple(sum_dic[data[1]],result)
#    else:
#        sum_dic[data[1]] = result
    
#for date in sum_dic:
#    real = train2_y[date]
#    value = sum_dic[date].index(max(sum_dic[date]))
#    value -= 1
#    if real == value:
#        count = count + 1
#train_score = count / len(sum_dic)

count = 0
sum_dic = {}
for data in test2_x:
    result = predict(data[0])
    if data[1] in sum_dic:
        sum_dic[data[1]] = sum_tuple(sum_dic[data[1]],result)
    else:
        sum_dic[data[1]] = result
    
for date in sum_dic:
    real = test2_y[date]
    value = sum_dic[date].index(max(sum_dic[date]))
    value -= 1
    if real == value:
        count = count + 1
test_score = count / len(sum_dic)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

fig, acc_ax = plt.subplots()

loss_ax = acc_ax.twinx()

loss_ax.plot(hist.history['loss'], 'y', label='train loss')
loss_ax.plot(hist.history['val_loss'], 'r', label='val loss')

acc_ax.plot(hist.history['categorical_accuracy'], 'b', label='train acc')
acc_ax.plot(hist.history['val_categorical_accuracy'], 'g', label='val acc')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuray')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()

# %%
print('단어 갯수 : '+num_word)
print('모델 레이어 및 노드 수 : ','첫 번째 레이어 - relu,',first_layer,', 두 번째 레이어 - relu,',second_layer)
print('epochs : ',ep,', batch_size : ', ba)
#print('train 데이터 정확도 : ', train_score)
print('test 데이터 정확도 : ', test_score)
# Out:
# 단어 갯수 : 8000
# 모델 레이어 및 노드 수 :  첫 번째 레이어 - relu, 3000 , 두 번째 레이어 - relu, 1000
# epochs :  100 , batch_size :  1000
# test 데이터 정확도 :  0.7905882352941176

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

fig, acc_ax = plt.subplots()

loss_ax = acc_ax.twinx()

loss_ax.plot(hist.history['loss'], 'y', label='train loss')
loss_ax.plot(hist.history['val_loss'], 'r', label='val loss')

acc_ax.plot(hist.history['categorical_accuracy'], 'b', label='train acc')
acc_ax.plot(hist.history['val_categorical_accuracy'], 'g', label='val acc')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuray')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()

# %%
print('단어 갯수 : '+num_word)
print('모델 레이어 및 노드 수 : ','첫 번째 레이어 - relu,',first_layer,', 두 번째 레이어 - relu,',second_layer)
print('epochs : ',ep,', batch_size : ', ba)
#print('train 데이터 정확도 : ', train_score)
print('test 데이터 정확도 : ', test_score)
# Out:
# 단어 갯수 : 8000
# 모델 레이어 및 노드 수 :  첫 번째 레이어 - relu, 3000 , 두 번째 레이어 - relu, 1000
# epochs :  80 , batch_size :  1000
# test 데이터 정확도 :  0.7670588235294118

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

fig, acc_ax = plt.subplots()

loss_ax = acc_ax.twinx()

loss_ax.plot(hist.history['loss'], 'y', label='train loss')
loss_ax.plot(hist.history['val_loss'], 'r', label='val loss')

acc_ax.plot(hist.history['categorical_accuracy'], 'b', label='train acc')
acc_ax.plot(hist.history['val_categorical_accuracy'], 'g', label='val acc')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuray')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()

# %%
print('단어 갯수 : '+num_word)
print('모델 레이어 및 노드 수 : ','첫 번째 레이어 - relu,',first_layer,', 두 번째 레이어 - relu,',second_layer)
print('epochs : ',ep,', batch_size : ', ba)
#print('train 데이터 정확도 : ', train_score)
print('test 데이터 정확도 : ', test_score)
# Out:
# 단어 갯수 : 8000
# 모델 레이어 및 노드 수 :  첫 번째 레이어 - relu, 3000 , 두 번째 레이어 - relu, 1000
# epochs :  60 , batch_size :  1000
# test 데이터 정확도 :  0.7741176470588236
