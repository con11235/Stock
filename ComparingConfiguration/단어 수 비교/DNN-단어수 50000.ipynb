# %%
# 사용할 데이터의 형태
data_type = '15'      # '1' : summarize X,개별 기사   '2' : summarize X,날짜별 기사
                    # '3' : summarize O,개별 기사   '4' : summarize O,날짜별 기사
normalized = 'done' # 'done' : 데이터 행별 normalize한 데이터     'not' : 데이터 행별 normalize 안한 데이터
erased_word = ''    # 제거된 단어 형태
num_word = '50000'   # 사용할 단어 수

# 돌려볼 모델의 구조
first_layer = 10000   # 모델의 첫 번째 레이어 수
second_layer = 5000  # 모델의 두 번째 레이어 수
ep = 80             # 모델의 에포크 수
ba = 1000            # 모델의 배치 사이즈

# %%
# 생성된 training, test의 x,y값을 pickle의 형태로 저장
import pickle
import os
path = os.getcwd()+'/pickles/'
if erased_word != '':
    erased_word = '_'+erased_word
with open(path+data_type+'train_x_'+str(num_word)+'_'+normalized+erased_word+'.pickle', 'rb') as f:
    train_x = pickle.load(f)
with open(path+data_type+'train_y_'+str(num_word)+'_'+normalized+erased_word+'.pickle', 'rb') as f:
    train_y = pickle.load(f)
with open(path+data_type+'train2_x_'+str(num_word)+'_'+normalized+erased_word+'.pickle', 'rb') as f:
    train2_x = pickle.load(f)
with open(path+data_type+'train2_y_'+str(num_word)+'_'+normalized+erased_word+'.pickle', 'rb') as f:
    train2_y = pickle.load(f)
with open(path+data_type+'test_x_'+str(num_word)+'_'+normalized+erased_word+'.pickle', 'rb') as f:
    test_x = pickle.load(f)
with open(path+data_type+'test_y_'+str(num_word)+'_'+normalized+erased_word+'.pickle', 'rb') as f:
    test_y = pickle.load(f)
with open(path+data_type+'test2_x_'+str(num_word)+'_'+normalized+erased_word+'.pickle', 'rb') as f:
    test2_x = pickle.load(f)
with open(path+data_type+'test2_y_'+str(num_word)+'_'+normalized+erased_word+'.pickle', 'rb') as f:
    test2_y = pickle.load(f)

# %%
# numpy 사용하여 float로 바꾸어주는 과정
import numpy as np
x_train = np.asarray(train_x).astype('float32')
y_train = np.asarray(train_y).astype('float32')
x_test = np.asarray(test_x).astype('float32')
y_test = np.asarray(test_y).astype('float32')

# %%
# DNN 학습 모델
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import optimizers
from tensorflow.keras import losses
from tensorflow.keras import metrics
#from tensorflow.keras.callbacks import EarlyStopping


#callbacks = [EarlyStopping(monitor='val_loss',patience = 20)]
model = models.Sequential()
n =len(x_train[0])
model.add(layers.Dense(first_layer,activation='relu'))#실제 쓸 단어갯수
model.add(layers.Dense(second_layer,activation='relu'))
model.add(layers.Dense(3,activation='softmax'))
model.compile(optimizer=optimizers.RMSprop(lr=0.001),loss = losses.categorical_crossentropy,metrics=[metrics.categorical_accuracy])

#hist = model.fit(x_train,y_train,epochs=ep,validation_data=(x_train2,y_train2),callbacks=callbacks,batch_size=ba, shuffle=True)
hist = model.fit(x_train,y_train,epochs=ep,validation_data=(x_test,y_test),batch_size=ba)
# Out:
# Epoch 1/80
# 6/6 [==============================] - 664s 111s/step - loss: 1.1109 - categorical_accuracy: 0.3436 - val_loss: 1.0987 - val_categorical_accuracy: 0.3626
# Epoch 2/80
# 6/6 [==============================] - 86s 14s/step - loss: 1.0941 - categorical_accuracy: 0.3543 - val_loss: 1.0923 - val_categorical_accuracy: 0.3802
# Epoch 3/80
# 6/6 [==============================] - 86s 14s/step - loss: 1.0884 - categorical_accuracy: 0.3891 - val_loss: 1.0908 - val_categorical_accuracy: 0.3748
# Epoch 4/80
# 6/6 [==============================] - 87s 14s/step - loss: 1.0680 - categorical_accuracy: 0.4190 - val_loss: 1.0838 - val_categorical_accuracy: 0.4191
# Epoch 5/80
# 6/6 [==============================] - 84s 14s/step - loss: 1.0504 - categorical_accuracy: 0.4370 - val_loss: 1.0722 - val_categorical_accuracy: 0.3922
# Epoch 6/80
# 6/6 [==============================] - 91s 15s/step - loss: 0.9930 - categorical_accuracy: 0.5061 - val_loss: 1.1200 - val_categorical_accuracy: 0.3933
# Epoch 7/80
# 6/6 [==============================] - 86s 14s/step - loss: 0.9578 - categorical_accuracy: 0.5209 - val_loss: 1.1312 - val_categorical_accuracy: 0.3828
# Epoch 8/80
# 6/6 [==============================] - 89s 15s/step - loss: 0.9147 - categorical_accuracy: 0.5840 - val_loss: 1.0971 - val_categorical_accuracy: 0.4151
# Epoch 9/80
# 6/6 [==============================] - 87s 15s/step - loss: 0.8577 - categorical_accuracy: 0.6223 - val_loss: 1.0146 - val_categorical_accuracy: 0.4780
# Epoch 10/80
# 6/6 [==============================] - 86s 14s/step - loss: 0.7928 - categorical_accuracy: 0.6577 - val_loss: 1.1245 - val_categorical_accuracy: 0.4705
# Epoch 11/80
# 6/6 [==============================] - 87s 14s/step - loss: 0.7460 - categorical_accuracy: 0.6859 - val_loss: 1.1325 - val_categorical_accuracy: 0.4693
# Epoch 12/80
# 6/6 [==============================] - 87s 15s/step - loss: 0.6871 - categorical_accuracy: 0.7030 - val_loss: 1.1442 - val_categorical_accuracy: 0.4536
# Epoch 13/80
# 6/6 [==============================] - 86s 14s/step - loss: 0.6586 - categorical_accuracy: 0.7289 - val_loss: 1.2753 - val_categorical_accuracy: 0.4264
# Epoch 14/80
# 6/6 [==============================] - 86s 14s/step - loss: 0.5320 - categorical_accuracy: 0.8138 - val_loss: 1.1261 - val_categorical_accuracy: 0.4834
# Epoch 15/80
# 6/6 [==============================] - 86s 14s/step - loss: 0.6208 - categorical_accuracy: 0.7287 - val_loss: 1.1307 - val_categorical_accuracy: 0.5150
# Epoch 16/80
# 6/6 [==============================] - 90s 15s/step - loss: 0.4727 - categorical_accuracy: 0.8207 - val_loss: 1.1922 - val_categorical_accuracy: 0.5169
# Epoch 17/80
# 6/6 [==============================] - 86s 14s/step - loss: 0.5375 - categorical_accuracy: 0.7684 - val_loss: 1.0249 - val_categorical_accuracy: 0.5178
# Epoch 18/80
# 6/6 [==============================] - 87s 15s/step - loss: 0.3466 - categorical_accuracy: 0.8838 - val_loss: 1.3313 - val_categorical_accuracy: 0.4639
# Epoch 19/80
# 6/6 [==============================] - 86s 14s/step - loss: 0.4869 - categorical_accuracy: 0.8034 - val_loss: 1.1234 - val_categorical_accuracy: 0.5213
# Epoch 20/80
# 6/6 [==============================] - 86s 14s/step - loss: 0.3610 - categorical_accuracy: 0.8602 - val_loss: 1.1869 - val_categorical_accuracy: 0.5117
# Epoch 21/80
# 6/6 [==============================] - 88s 15s/step - loss: 0.2905 - categorical_accuracy: 0.8997 - val_loss: 1.6809 - val_categorical_accuracy: 0.4925
# Epoch 22/80
# 6/6 [==============================] - 99s 17s/step - loss: 0.3019 - categorical_accuracy: 0.8927 - val_loss: 1.3103 - val_categorical_accuracy: 0.5105
# Epoch 23/80
# 6/6 [==============================] - 99s 16s/step - loss: 0.3754 - categorical_accuracy: 0.8481 - val_loss: 1.1447 - val_categorical_accuracy: 0.5485
# Epoch 24/80
# 6/6 [==============================] - 88s 15s/step - loss: 0.1744 - categorical_accuracy: 0.9498 - val_loss: 1.6934 - val_categorical_accuracy: 0.5061
# Epoch 25/80
# 6/6 [==============================] - 91s 15s/step - loss: 0.3248 - categorical_accuracy: 0.8704 - val_loss: 1.2048 - val_categorical_accuracy: 0.5452
# Epoch 26/80
# 6/6 [==============================] - 87s 14s/step - loss: 0.1216 - categorical_accuracy: 0.9703 - val_loss: 1.6387 - val_categorical_accuracy: 0.4904
# Epoch 27/80
# 6/6 [==============================] - 86s 14s/step - loss: 0.3818 - categorical_accuracy: 0.8551 - val_loss: 1.2418 - val_categorical_accuracy: 0.5516
# Epoch 28/80
# 6/6 [==============================] - 86s 14s/step - loss: 0.0915 - categorical_accuracy: 0.9819 - val_loss: 1.6298 - val_categorical_accuracy: 0.5288
# Epoch 29/80
# 6/6 [==============================] - 86s 14s/step - loss: 0.3208 - categorical_accuracy: 0.8733 - val_loss: 1.2618 - val_categorical_accuracy: 0.5530
# Epoch 30/80
# 6/6 [==============================] - 86s 14s/step - loss: 0.0616 - categorical_accuracy: 0.9886 - val_loss: 1.3594 - val_categorical_accuracy: 0.5516
# Epoch 31/80
# 6/6 [==============================] - 86s 14s/step - loss: 0.0578 - categorical_accuracy: 0.9860 - val_loss: 2.2874 - val_categorical_accuracy: 0.4611
# Epoch 32/80
# 6/6 [==============================] - 89s 15s/step - loss: 0.4787 - categorical_accuracy: 0.8557 - val_loss: 1.2967 - val_categorical_accuracy: 0.5445
# Epoch 33/80
# 6/6 [==============================] - 88s 15s/step - loss: 0.0449 - categorical_accuracy: 0.9918 - val_loss: 1.4074 - val_categorical_accuracy: 0.5466
# Epoch 34/80
# 6/6 [==============================] - 93s 16s/step - loss: 0.0346 - categorical_accuracy: 0.9915 - val_loss: 1.5189 - val_categorical_accuracy: 0.5408
# Epoch 35/80
# 6/6 [==============================] - 86s 14s/step - loss: 0.0331 - categorical_accuracy: 0.9922 - val_loss: 2.0089 - val_categorical_accuracy: 0.4991
# Epoch 36/80
# 6/6 [==============================] - 85s 14s/step - loss: 0.5699 - categorical_accuracy: 0.8642 - val_loss: 1.3555 - val_categorical_accuracy: 0.5516
# Epoch 37/80
# 6/6 [==============================] - 86s 14s/step - loss: 0.0337 - categorical_accuracy: 0.9946 - val_loss: 1.4406 - val_categorical_accuracy: 0.5485
# Epoch 38/80
# 6/6 [==============================] - 99s 16s/step - loss: 0.0261 - categorical_accuracy: 0.9938 - val_loss: 1.5112 - val_categorical_accuracy: 0.5488
# Epoch 39/80
# 6/6 [==============================] - 93s 16s/step - loss: 0.0244 - categorical_accuracy: 0.9933 - val_loss: 2.3653 - val_categorical_accuracy: 0.4951
# Epoch 40/80
# 6/6 [==============================] - 90s 15s/step - loss: 0.4977 - categorical_accuracy: 0.8500 - val_loss: 1.4343 - val_categorical_accuracy: 0.5502
# Epoch 41/80
# 6/6 [==============================] - 86s 14s/step - loss: 0.0241 - categorical_accuracy: 0.9955 - val_loss: 1.5276 - val_categorical_accuracy: 0.5530
# Epoch 42/80
# 6/6 [==============================] - 88s 15s/step - loss: 0.0188 - categorical_accuracy: 0.9956 - val_loss: 1.5871 - val_categorical_accuracy: 0.5492
# Epoch 43/80
# 6/6 [==============================] - 87s 15s/step - loss: 0.0162 - categorical_accuracy: 0.9956 - val_loss: 1.6537 - val_categorical_accuracy: 0.5476
# Epoch 44/80
# 6/6 [==============================] - 89s 15s/step - loss: 0.0147 - categorical_accuracy: 0.9951 - val_loss: 1.8091 - val_categorical_accuracy: 0.5478
# Epoch 45/80
# 6/6 [==============================] - 88s 15s/step - loss: 0.2971 - categorical_accuracy: 0.9442 - val_loss: 4.2998 - val_categorical_accuracy: 0.4337
# Epoch 46/80
# 6/6 [==============================] - 86s 14s/step - loss: 0.9289 - categorical_accuracy: 0.8004 - val_loss: 1.4829 - val_categorical_accuracy: 0.5504
# Epoch 47/80
# 6/6 [==============================] - 90s 15s/step - loss: 0.0211 - categorical_accuracy: 0.9966 - val_loss: 1.5400 - val_categorical_accuracy: 0.5506
# Epoch 48/80
# 6/6 [==============================] - 85s 14s/step - loss: 0.0170 - categorical_accuracy: 0.9966 - val_loss: 1.6084 - val_categorical_accuracy: 0.5509
# Epoch 49/80
# 6/6 [==============================] - 86s 14s/step - loss: 0.0142 - categorical_accuracy: 0.9973 - val_loss: 1.6718 - val_categorical_accuracy: 0.5527
# Epoch 50/80
# 6/6 [==============================] - 90s 15s/step - loss: 0.0129 - categorical_accuracy: 0.9960 - val_loss: 1.7315 - val_categorical_accuracy: 0.5471
# Epoch 51/80
# 6/6 [==============================] - 86s 14s/step - loss: 0.0117 - categorical_accuracy: 0.9958 - val_loss: 1.7804 - val_categorical_accuracy: 0.5474
# Epoch 52/80
# 6/6 [==============================] - 86s 14s/step - loss: 0.0119 - categorical_accuracy: 0.9955 - val_loss: 1.8742 - val_categorical_accuracy: 0.5384
# Epoch 53/80
# 6/6 [==============================] - 88s 15s/step - loss: 0.0144 - categorical_accuracy: 0.9949 - val_loss: 2.1132 - val_categorical_accuracy: 0.5349
# Epoch 54/80
# 6/6 [==============================] - 85s 14s/step - loss: 0.8635 - categorical_accuracy: 0.8345 - val_loss: 1.9636 - val_categorical_accuracy: 0.5284
# Epoch 55/80
# 6/6 [==============================] - 89s 15s/step - loss: 0.0194 - categorical_accuracy: 0.9955 - val_loss: 1.6830 - val_categorical_accuracy: 0.5499
# Epoch 56/80
# 6/6 [==============================] - 89s 15s/step - loss: 0.0111 - categorical_accuracy: 0.9966 - val_loss: 1.7132 - val_categorical_accuracy: 0.5478
# Epoch 57/80
# 6/6 [==============================] - 87s 14s/step - loss: 0.0095 - categorical_accuracy: 0.9969 - val_loss: 1.7731 - val_categorical_accuracy: 0.5546
# Epoch 58/80
# 6/6 [==============================] - 87s 14s/step - loss: 0.0095 - categorical_accuracy: 0.9964 - val_loss: 1.8050 - val_categorical_accuracy: 0.5497
# Epoch 59/80
# 6/6 [==============================] - 87s 14s/step - loss: 0.0087 - categorical_accuracy: 0.9975 - val_loss: 1.8763 - val_categorical_accuracy: 0.5553
# Epoch 60/80
# 6/6 [==============================] - 85s 14s/step - loss: 0.0090 - categorical_accuracy: 0.9960 - val_loss: 1.9100 - val_categorical_accuracy: 0.5457
# Epoch 61/80
# 6/6 [==============================] - 87s 14s/step - loss: 0.0113 - categorical_accuracy: 0.9964 - val_loss: 1.9292 - val_categorical_accuracy: 0.5476
# Epoch 62/80
# 6/6 [==============================] - 86s 14s/step - loss: 0.6081 - categorical_accuracy: 0.9039 - val_loss: 4.1061 - val_categorical_accuracy: 0.3943
# Epoch 63/80
# 6/6 [==============================] - 88s 15s/step - loss: 0.5219 - categorical_accuracy: 0.8479 - val_loss: 1.6765 - val_categorical_accuracy: 0.5488
# Epoch 64/80
# 6/6 [==============================] - 86s 14s/step - loss: 0.0105 - categorical_accuracy: 0.9975 - val_loss: 1.6898 - val_categorical_accuracy: 0.5462
# Epoch 65/80
# 6/6 [==============================] - 94s 16s/step - loss: 0.0091 - categorical_accuracy: 0.9978 - val_loss: 1.7337 - val_categorical_accuracy: 0.5471
# Epoch 66/80
# 6/6 [==============================] - 100s 17s/step - loss: 0.0083 - categorical_accuracy: 0.9973 - val_loss: 1.7881 - val_categorical_accuracy: 0.5445
# Epoch 67/80
# 6/6 [==============================] - 92s 15s/step - loss: 0.0077 - categorical_accuracy: 0.9976 - val_loss: 1.8244 - val_categorical_accuracy: 0.5481
# Epoch 68/80
# 6/6 [==============================] - 90s 15s/step - loss: 0.0073 - categorical_accuracy: 0.9975 - val_loss: 1.9073 - val_categorical_accuracy: 0.5445
# Epoch 69/80
# 6/6 [==============================] - 88s 15s/step - loss: 0.0085 - categorical_accuracy: 0.9964 - val_loss: 1.9416 - val_categorical_accuracy: 0.5469
# Epoch 70/80
# 6/6 [==============================] - 86s 14s/step - loss: 0.0067 - categorical_accuracy: 0.9980 - val_loss: 1.9501 - val_categorical_accuracy: 0.5502
# Epoch 71/80
# 6/6 [==============================] - 95s 16s/step - loss: 0.0073 - categorical_accuracy: 0.9973 - val_loss: 2.0309 - val_categorical_accuracy: 0.5523
# Epoch 72/80
# 6/6 [==============================] - 115s 19s/step - loss: 0.0087 - categorical_accuracy: 0.9969 - val_loss: 2.1596 - val_categorical_accuracy: 0.5464
# Epoch 73/80
# 6/6 [==============================] - 120s 20s/step - loss: 1.2498 - categorical_accuracy: 0.7920 - val_loss: 2.5515 - val_categorical_accuracy: 0.4958
# Epoch 74/80
# 6/6 [==============================] - 119s 20s/step - loss: 0.0453 - categorical_accuracy: 0.9806 - val_loss: 1.8998 - val_categorical_accuracy: 0.5443
# Epoch 75/80
# 6/6 [==============================] - 106s 18s/step - loss: 0.0066 - categorical_accuracy: 0.9980 - val_loss: 1.9039 - val_categorical_accuracy: 0.5464
# Epoch 76/80
# 6/6 [==============================] - 106s 18s/step - loss: 0.0062 - categorical_accuracy: 0.9980 - val_loss: 1.9225 - val_categorical_accuracy: 0.5462
# Epoch 77/80
# 6/6 [==============================] - 106s 18s/step - loss: 0.0059 - categorical_accuracy: 0.9980 - val_loss: 1.9489 - val_categorical_accuracy: 0.5495
# Epoch 78/80
# 6/6 [==============================] - 109s 18s/step - loss: 0.0056 - categorical_accuracy: 0.9978 - val_loss: 1.9704 - val_categorical_accuracy: 0.5509
# Epoch 79/80
# 6/6 [==============================] - 106s 18s/step - loss: 0.0056 - categorical_accuracy: 0.9980 - val_loss: 2.0116 - val_categorical_accuracy: 0.5497
# Epoch 80/80
# 6/6 [==============================] - 105s 18s/step - loss: 0.0057 - categorical_accuracy: 0.9975 - val_loss: 2.0788 - val_categorical_accuracy: 0.5431

# %%
# 모델의 예측값을 튜플로 반환하는 함수
def predict(x):
    data = np.expand_dims(np.asarray(x).astype('float32'),axis=0)
    result = model.predict(data)
    return tuple(result[0])

# %%
# 모든 날짜의 예측값들을 합치기 위한 튜플의 합 함수
def sum_tuple(a,b):
    return (a[0]+b[0],a[1]+b[1],a[2]+b[2])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

fig, acc_ax = plt.subplots()

loss_ax = acc_ax.twinx()

loss_ax.plot(hist.history['loss'], 'y', label='train loss')
loss_ax.plot(hist.history['val_loss'], 'r', label='val loss')

acc_ax.plot(hist.history['categorical_accuracy'], 'b', label='train acc')
acc_ax.plot(hist.history['val_categorical_accuracy'], 'g', label='val acc')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuray')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()

# %%
# Test set에 대한 예측 및 예측 정확도의 계산
import re

count = 0
sum_dic = {}
for data in train2_x:
    result = predict(data[0])
    if data[1] in sum_dic:
        sum_dic[data[1]] = sum_tuple(sum_dic[data[1]],result)
    else:
        sum_dic[data[1]] = result
    
for date in sum_dic:
    real = train2_y[date]
    value = sum_dic[date].index(max(sum_dic[date]))
    value -= 1
    if real == value:
        count = count + 1
train_score = count / len(sum_dic)

count = 0
sum_dic = {}
for data in test2_x:
    result = predict(data[0])
    if data[1] in sum_dic:
        sum_dic[data[1]] = sum_tuple(sum_dic[data[1]],result)
    else:
        sum_dic[data[1]] = result
    
for date in sum_dic:
    real = test2_y[date]
    value = sum_dic[date].index(max(sum_dic[date]))
    value -= 1
    if real == value:
        count = count + 1
test_score = count / len(sum_dic)

# %%
print('단어 갯수 : '+num_word)
print('모델 레이어 및 노드 수 : ','첫 번째 레이어 - relu,',first_layer,', 두 번째 레이어 - relu,',second_layer)
print('epochs : ',ep,', batch_size : ', ba)
print('train 데이터 정확도 : ', train_score)
print('test 데이터 정확도 : ', test_score)
# Out:
# 단어 갯수 : 50000
# 모델 레이어 및 노드 수 :  첫 번째 레이어 - relu, 10000 , 두 번째 레이어 - relu, 5000
# epochs :  80 , batch_size :  1000
# train 데이터 정확도 :  1.0
# test 데이터 정확도 :  0.7838616714697406
