# %%
# 사용할 데이터의 형태
data_type = '8'      # '1' : summarize X,개별 기사   '2' : summarize X,날짜별 기사
                    # '3' : summarize O,개별 기사   '4' : summarize O,날짜별 기사
normalized = 'done' # 'done' : 데이터 행별 normalize한 데이터     'not' : 데이터 행별 normalize 안한 데이터
erased_word = ''    # 제거된 단어 형태
num_word = '7000'   # 사용할 단어 수

# 돌려볼 모델의 구조
first_layer = 3000   # 모델의 첫 번째 레이어 수
second_layer = 1000  # 모델의 두 번째 레이어 수
ep = 60             # 모델의 에포크 수
ba = 1000            # 모델의 배치 사이즈

# %%
# 생성된 training, test의 x,y값을 pickle의 형태로 저장
import pickle
import os
path = os.getcwd()+'/pickles/'
if erased_word != '':
    erased_word = '_'+erased_word
with open(path+data_type+'train_x_'+str(num_word)+'_'+normalized+erased_word+'.pickle', 'rb') as f:
    train_x = pickle.load(f)
with open(path+data_type+'train_y_'+str(num_word)+'_'+normalized+erased_word+'.pickle', 'rb') as f:
    train_y = pickle.load(f)
with open(path+data_type+'train2_x_'+str(num_word)+'_'+normalized+erased_word+'.pickle', 'rb') as f:
    train2_x = pickle.load(f)
with open(path+data_type+'train2_y_'+str(num_word)+'_'+normalized+erased_word+'.pickle', 'rb') as f:
    train2_y = pickle.load(f)
with open(path+data_type+'test_x_'+str(num_word)+'_'+normalized+erased_word+'.pickle', 'rb') as f:
    test_x = pickle.load(f)
with open(path+data_type+'test_y_'+str(num_word)+'_'+normalized+erased_word+'.pickle', 'rb') as f:
    test_y = pickle.load(f)
with open(path+data_type+'test2_x_'+str(num_word)+'_'+normalized+erased_word+'.pickle', 'rb') as f:
    test2_x = pickle.load(f)
with open(path+data_type+'test2_y_'+str(num_word)+'_'+normalized+erased_word+'.pickle', 'rb') as f:
    test2_y = pickle.load(f)

# %%
# numpy 사용하여 float로 바꾸어주는 과정
import numpy as np
x_train = np.asarray(train_x).astype('float32')
y_train = np.asarray(train_y).astype('float32')
x_test = np.asarray(test_x).astype('float32')
y_test = np.asarray(test_y).astype('float32')

# %%
# DNN 학습 모델
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import optimizers
from tensorflow.keras import losses
from tensorflow.keras import metrics
#from tensorflow.keras.callbacks import EarlyStopping


#callbacks = [EarlyStopping(monitor='val_loss',patience = 20)]
model = models.Sequential()
n =len(x_train[0])
model.add(layers.Dense(first_layer,activation='relu'))#실제 쓸 단어갯수
model.add(layers.Dense(second_layer,activation='relu'))
model.add(layers.Dense(3,activation='softmax'))
model.compile(optimizer=optimizers.RMSprop(lr=0.001),loss = losses.categorical_crossentropy,metrics=[metrics.categorical_accuracy])

#hist = model.fit(x_train,y_train,epochs=ep,validation_data=(x_train2,y_train2),callbacks=callbacks,batch_size=ba, shuffle=True)
hist = model.fit(x_train,y_train,epochs=ep,validation_data=(x_test,y_test),batch_size=ba)
# Out:
# Epoch 1/60
# 10/10 [==============================] - 19s 2s/step - loss: 1.0922 - categorical_accuracy: 0.3719 - val_loss: 1.0882 - val_categorical_accuracy: 0.3708
# Epoch 2/60
# 10/10 [==============================] - 13s 1s/step - loss: 1.0751 - categorical_accuracy: 0.3920 - val_loss: 1.0856 - val_categorical_accuracy: 0.3749
# Epoch 3/60
# 10/10 [==============================] - 13s 1s/step - loss: 1.0548 - categorical_accuracy: 0.4465 - val_loss: 1.0818 - val_categorical_accuracy: 0.4013
# Epoch 4/60
# 10/10 [==============================] - 13s 1s/step - loss: 1.0506 - categorical_accuracy: 0.4429 - val_loss: 1.0538 - val_categorical_accuracy: 0.4390
# Epoch 5/60
# 10/10 [==============================] - 13s 1s/step - loss: 0.9905 - categorical_accuracy: 0.4967 - val_loss: 1.0560 - val_categorical_accuracy: 0.4267
# Epoch 6/60
# 10/10 [==============================] - 12s 1s/step - loss: 0.9785 - categorical_accuracy: 0.5003 - val_loss: 1.1099 - val_categorical_accuracy: 0.3910
# Epoch 7/60
# 10/10 [==============================] - 13s 1s/step - loss: 0.9473 - categorical_accuracy: 0.5379 - val_loss: 1.0466 - val_categorical_accuracy: 0.4522
# Epoch 8/60
# 10/10 [==============================] - 12s 1s/step - loss: 0.9221 - categorical_accuracy: 0.5683 - val_loss: 1.0895 - val_categorical_accuracy: 0.4080
# Epoch 9/60
# 10/10 [==============================] - 13s 1s/step - loss: 0.8779 - categorical_accuracy: 0.5932 - val_loss: 1.0635 - val_categorical_accuracy: 0.4306
# Epoch 10/60
# 10/10 [==============================] - 13s 1s/step - loss: 0.8628 - categorical_accuracy: 0.6067 - val_loss: 1.0549 - val_categorical_accuracy: 0.4709
# Epoch 11/60
# 10/10 [==============================] - 13s 1s/step - loss: 0.8198 - categorical_accuracy: 0.6331 - val_loss: 1.0687 - val_categorical_accuracy: 0.4672
# Epoch 12/60
# 10/10 [==============================] - 13s 1s/step - loss: 0.7911 - categorical_accuracy: 0.6507 - val_loss: 1.1895 - val_categorical_accuracy: 0.4517
# Epoch 13/60
# 10/10 [==============================] - 15s 1s/step - loss: 0.7549 - categorical_accuracy: 0.6627 - val_loss: 1.0716 - val_categorical_accuracy: 0.4643
# Epoch 14/60
# 10/10 [==============================] - 14s 1s/step - loss: 0.7394 - categorical_accuracy: 0.6826 - val_loss: 1.2365 - val_categorical_accuracy: 0.4084
# Epoch 15/60
# 10/10 [==============================] - 13s 1s/step - loss: 0.7210 - categorical_accuracy: 0.7049 - val_loss: 1.1032 - val_categorical_accuracy: 0.4917
# Epoch 16/60
# 10/10 [==============================] - 12s 1s/step - loss: 0.6691 - categorical_accuracy: 0.7290 - val_loss: 1.1051 - val_categorical_accuracy: 0.4658
# Epoch 17/60
# 10/10 [==============================] - 12s 1s/step - loss: 0.6281 - categorical_accuracy: 0.7451 - val_loss: 1.4041 - val_categorical_accuracy: 0.4816
# Epoch 18/60
# 10/10 [==============================] - 12s 1s/step - loss: 0.6285 - categorical_accuracy: 0.7403 - val_loss: 1.2171 - val_categorical_accuracy: 0.4857
# Epoch 19/60
# 10/10 [==============================] - 13s 1s/step - loss: 0.6115 - categorical_accuracy: 0.7450 - val_loss: 1.1595 - val_categorical_accuracy: 0.4987
# Epoch 20/60
# 10/10 [==============================] - 13s 1s/step - loss: 0.5602 - categorical_accuracy: 0.7697 - val_loss: 1.3514 - val_categorical_accuracy: 0.4690
# Epoch 21/60
# 10/10 [==============================] - 13s 1s/step - loss: 0.5308 - categorical_accuracy: 0.7821 - val_loss: 1.2862 - val_categorical_accuracy: 0.4993
# Epoch 22/60
# 10/10 [==============================] - 12s 1s/step - loss: 0.4969 - categorical_accuracy: 0.8091 - val_loss: 1.5172 - val_categorical_accuracy: 0.4894
# Epoch 23/60
# 10/10 [==============================] - 12s 1s/step - loss: 0.5056 - categorical_accuracy: 0.7924 - val_loss: 1.2353 - val_categorical_accuracy: 0.4699
# Epoch 24/60
# 10/10 [==============================] - 12s 1s/step - loss: 0.4191 - categorical_accuracy: 0.8346 - val_loss: 1.4317 - val_categorical_accuracy: 0.5054
# Epoch 25/60
# 10/10 [==============================] - 12s 1s/step - loss: 0.4105 - categorical_accuracy: 0.8346 - val_loss: 1.3530 - val_categorical_accuracy: 0.4641
# Epoch 26/60
# 10/10 [==============================] - 13s 1s/step - loss: 0.3980 - categorical_accuracy: 0.8433 - val_loss: 1.4950 - val_categorical_accuracy: 0.4960
# Epoch 27/60
# 10/10 [==============================] - 12s 1s/step - loss: 0.3618 - categorical_accuracy: 0.8622 - val_loss: 1.4457 - val_categorical_accuracy: 0.4488
# Epoch 28/60
# 10/10 [==============================] - 12s 1s/step - loss: 0.3148 - categorical_accuracy: 0.8876 - val_loss: 1.5767 - val_categorical_accuracy: 0.4688
# Epoch 29/60
# 10/10 [==============================] - 12s 1s/step - loss: 0.3660 - categorical_accuracy: 0.8496 - val_loss: 1.4695 - val_categorical_accuracy: 0.5130
# Epoch 30/60
# 10/10 [==============================] - 12s 1s/step - loss: 0.2854 - categorical_accuracy: 0.8926 - val_loss: 1.8449 - val_categorical_accuracy: 0.5024
# Epoch 31/60
# 10/10 [==============================] - 13s 1s/step - loss: 0.2853 - categorical_accuracy: 0.8866 - val_loss: 1.7408 - val_categorical_accuracy: 0.4845
# Epoch 32/60
# 10/10 [==============================] - 12s 1s/step - loss: 0.2709 - categorical_accuracy: 0.8936 - val_loss: 1.8704 - val_categorical_accuracy: 0.4049
# Epoch 33/60
# 10/10 [==============================] - 12s 1s/step - loss: 0.2641 - categorical_accuracy: 0.8982 - val_loss: 1.6417 - val_categorical_accuracy: 0.5179
# Epoch 34/60
# 10/10 [==============================] - 11s 1s/step - loss: 0.2895 - categorical_accuracy: 0.8783 - val_loss: 1.5342 - val_categorical_accuracy: 0.5300
# Epoch 35/60
# 10/10 [==============================] - 7s 693ms/step - loss: 0.1271 - categorical_accuracy: 0.9652 - val_loss: 1.9121 - val_categorical_accuracy: 0.4513
# Epoch 36/60
# 10/10 [==============================] - 7s 690ms/step - loss: 0.5633 - categorical_accuracy: 0.8284 - val_loss: 1.5080 - val_categorical_accuracy: 0.5219
# Epoch 37/60
# 10/10 [==============================] - 8s 769ms/step - loss: 0.1054 - categorical_accuracy: 0.9734 - val_loss: 1.6935 - val_categorical_accuracy: 0.5182
# Epoch 38/60
# 10/10 [==============================] - 8s 756ms/step - loss: 0.2522 - categorical_accuracy: 0.9023 - val_loss: 1.6594 - val_categorical_accuracy: 0.5167
# Epoch 39/60
# 10/10 [==============================] - 7s 743ms/step - loss: 0.1183 - categorical_accuracy: 0.9678 - val_loss: 1.7431 - val_categorical_accuracy: 0.5189
# Epoch 40/60
# 10/10 [==============================] - 8s 764ms/step - loss: 0.3494 - categorical_accuracy: 0.8954 - val_loss: 1.5031 - val_categorical_accuracy: 0.5251
# Epoch 41/60
# 10/10 [==============================] - 10s 965ms/step - loss: 0.0983 - categorical_accuracy: 0.9730 - val_loss: 1.9002 - val_categorical_accuracy: 0.5197
# Epoch 42/60
# 10/10 [==============================] - 8s 832ms/step - loss: 0.0775 - categorical_accuracy: 0.9767 - val_loss: 2.0459 - val_categorical_accuracy: 0.5039
# Epoch 43/60
# 10/10 [==============================] - 8s 766ms/step - loss: 0.7396 - categorical_accuracy: 0.8124 - val_loss: 1.6103 - val_categorical_accuracy: 0.5243
# Epoch 44/60
# 10/10 [==============================] - 8s 804ms/step - loss: 0.0800 - categorical_accuracy: 0.9802 - val_loss: 1.8343 - val_categorical_accuracy: 0.5237
# Epoch 45/60
# 10/10 [==============================] - 9s 870ms/step - loss: 0.0691 - categorical_accuracy: 0.9783 - val_loss: 2.0147 - val_categorical_accuracy: 0.5172
# Epoch 46/60
# 10/10 [==============================] - 7s 746ms/step - loss: 0.0775 - categorical_accuracy: 0.9733 - val_loss: 3.5992 - val_categorical_accuracy: 0.4848
# Epoch 47/60
# 10/10 [==============================] - 8s 763ms/step - loss: 0.6157 - categorical_accuracy: 0.8097 - val_loss: 1.7128 - val_categorical_accuracy: 0.5207
# Epoch 48/60
# 10/10 [==============================] - 7s 713ms/step - loss: 0.0637 - categorical_accuracy: 0.9826 - val_loss: 1.9522 - val_categorical_accuracy: 0.5239
# Epoch 49/60
# 10/10 [==============================] - 8s 785ms/step - loss: 0.0547 - categorical_accuracy: 0.9842 - val_loss: 2.0709 - val_categorical_accuracy: 0.5180
# Epoch 50/60
# 10/10 [==============================] - 7s 748ms/step - loss: 0.2240 - categorical_accuracy: 0.9357 - val_loss: 3.4580 - val_categorical_accuracy: 0.4104
# Epoch 51/60
# 10/10 [==============================] - 8s 845ms/step - loss: 0.2579 - categorical_accuracy: 0.9358 - val_loss: 1.7571 - val_categorical_accuracy: 0.5261
# Epoch 52/60
# 10/10 [==============================] - 7s 744ms/step - loss: 0.0530 - categorical_accuracy: 0.9843 - val_loss: 1.9878 - val_categorical_accuracy: 0.5249
# Epoch 53/60
# 10/10 [==============================] - 8s 777ms/step - loss: 0.2694 - categorical_accuracy: 0.9040 - val_loss: 1.7216 - val_categorical_accuracy: 0.5221
# Epoch 54/60
# 10/10 [==============================] - 8s 818ms/step - loss: 0.0513 - categorical_accuracy: 0.9852 - val_loss: 1.9306 - val_categorical_accuracy: 0.5231
# Epoch 55/60
# 10/10 [==============================] - 8s 791ms/step - loss: 0.0444 - categorical_accuracy: 0.9849 - val_loss: 2.0676 - val_categorical_accuracy: 0.5109
# Epoch 56/60
# 10/10 [==============================] - 8s 778ms/step - loss: 0.4052 - categorical_accuracy: 0.8836 - val_loss: 1.6670 - val_categorical_accuracy: 0.5173
# Epoch 57/60
# 10/10 [==============================] - 8s 764ms/step - loss: 0.0477 - categorical_accuracy: 0.9856 - val_loss: 1.9131 - val_categorical_accuracy: 0.5221
# Epoch 58/60
# 10/10 [==============================] - 7s 733ms/step - loss: 0.0407 - categorical_accuracy: 0.9845 - val_loss: 2.1698 - val_categorical_accuracy: 0.5216
# Epoch 59/60
# 10/10 [==============================] - 8s 790ms/step - loss: 0.3068 - categorical_accuracy: 0.9237 - val_loss: 2.1649 - val_categorical_accuracy: 0.5136
# Epoch 60/60
# 10/10 [==============================] - 8s 778ms/step - loss: 0.0556 - categorical_accuracy: 0.9834 - val_loss: 1.9417 - val_categorical_accuracy: 0.5214

# %%
# 모델의 예측값을 튜플로 반환하는 함수
def predict(x):
    data = np.expand_dims(np.asarray(x).astype('float32'),axis=0)
    result = model.predict(data)
    return tuple(result[0])

# %%
# 모든 날짜의 예측값들을 합치기 위한 튜플의 합 함수
def sum_tuple(a,b):
    return (a[0]+b[0],a[1]+b[1],a[2]+b[2])

# %%
# Test set에 대한 예측 및 예측 정확도의 계산
import re
"""
count = 0
sum_dic = {}
for data in train2_x:
    result = predict(data[0])
    if data[1] in sum_dic:
        sum_dic[data[1]] = sum_tuple(sum_dic[data[1]],result)
    else:
        sum_dic[data[1]] = result
    
for date in sum_dic:
    real = train2_y[date]
    value = sum_dic[date].index(max(sum_dic[date]))
    value -= 1
    if real == value:
        count = count + 1
train_score = count / len(sum_dic)
"""
count = 0
sum_dic = {}
for data in test2_x:
    result = predict(data[0])
    if data[1] in sum_dic:
        sum_dic[data[1]] = sum_tuple(sum_dic[data[1]],result)
    else:
        sum_dic[data[1]] = result
    
for date in sum_dic:
    real = test2_y[date]
    value = sum_dic[date].index(max(sum_dic[date]))
    value -= 1
    if real == value:
        count = count + 1
test_score = count / len(sum_dic)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

fig, acc_ax = plt.subplots()

loss_ax = acc_ax.twinx()

loss_ax.plot(hist.history['loss'], 'y', label='train loss')
loss_ax.plot(hist.history['val_loss'], 'r', label='val loss')

acc_ax.plot(hist.history['categorical_accuracy'], 'b', label='train acc')
acc_ax.plot(hist.history['val_categorical_accuracy'], 'g', label='val acc')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuray')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()

# %%
print('단어 갯수 : '+num_word)
print('모델 레이어 및 노드 수 : ','첫 번째 레이어 - relu,',first_layer,', 두 번째 레이어 - relu,',second_layer)
print('epochs : ',ep,', batch_size : ', ba)
#print('train 데이터 정확도 : ', train_score)
print('test 데이터 정확도 : ', test_score)
# Out:
# 단어 갯수 : 7000
# 모델 레이어 및 노드 수 :  첫 번째 레이어 - relu, 3000 , 두 번째 레이어 - relu, 1000
# epochs :  100 , batch_size :  1000
# test 데이터 정확도 :  0.7811764705882352

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

fig, acc_ax = plt.subplots()

loss_ax = acc_ax.twinx()

loss_ax.plot(hist.history['loss'], 'y', label='train loss')
loss_ax.plot(hist.history['val_loss'], 'r', label='val loss')

acc_ax.plot(hist.history['categorical_accuracy'], 'b', label='train acc')
acc_ax.plot(hist.history['val_categorical_accuracy'], 'g', label='val acc')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuray')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()

# %%
print('단어 갯수 : '+num_word)
print('모델 레이어 및 노드 수 : ','첫 번째 레이어 - relu,',first_layer,', 두 번째 레이어 - relu,',second_layer)
print('epochs : ',ep,', batch_size : ', ba)
print('train 데이터 정확도 : ', train_score)
print('test 데이터 정확도 : ', test_score)
# Out:
# 단어 갯수 : 7000
# 모델 레이어 및 노드 수 :  첫 번째 레이어 - relu, 3000 , 두 번째 레이어 - relu, 1000
# epochs :  80 , batch_size :  1000
# train 데이터 정확도 :  1.0
# test 데이터 정확도 :  0.7647058823529411

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

fig, acc_ax = plt.subplots()

loss_ax = acc_ax.twinx()

loss_ax.plot(hist.history['loss'], 'y', label='train loss')
loss_ax.plot(hist.history['val_loss'], 'r', label='val loss')

acc_ax.plot(hist.history['categorical_accuracy'], 'b', label='train acc')
acc_ax.plot(hist.history['val_categorical_accuracy'], 'g', label='val acc')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuray')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()

# %%
print('단어 갯수 : '+num_word)
print('모델 레이어 및 노드 수 : ','첫 번째 레이어 - relu,',first_layer,', 두 번째 레이어 - relu,',second_layer)
print('epochs : ',ep,', batch_size : ', ba)
#print('train 데이터 정확도 : ', train_score)
print('test 데이터 정확도 : ', test_score)
# Out:
# 단어 갯수 : 7000
# 모델 레이어 및 노드 수 :  첫 번째 레이어 - relu, 3000 , 두 번째 레이어 - relu, 1000
# epochs :  60 , batch_size :  1000
# test 데이터 정확도 :  0.76
