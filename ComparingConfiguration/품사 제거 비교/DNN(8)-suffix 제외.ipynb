# %%
# 사용할 데이터의 형태
data_type = '8'      # '1' : summarize X,개별 기사   '2' : summarize X,날짜별 기사
                    # '3' : summarize O,개별 기사   '4' : summarize O,날짜별 기사
normalized = 'done' # 'done' : 데이터 행별 normalize한 데이터     'not' : 데이터 행별 normalize 안한 데이터
erased_word = 'S'    # 제거된 단어 형태
num_word = '6000'   # 사용할 단어 수

# 돌려볼 모델의 구조
first_layer = 3000   # 모델의 첫 번째 레이어 수
second_layer = 1000  # 모델의 두 번째 레이어 수
ep = 60             # 모델의 에포크 수
ba = 1000            # 모델의 배치 사이즈

# %%
# 생성된 training, test의 x,y값을 pickle의 형태로 저장
import pickle
import os
path = os.getcwd()+'/pickles/'
if erased_word != '':
    erased_word = '_'+erased_word
with open(path+data_type+'train_x_'+str(num_word)+'_'+normalized+erased_word+'.pickle', 'rb') as f:
    train_x = pickle.load(f)
with open(path+data_type+'train_y_'+str(num_word)+'_'+normalized+erased_word+'.pickle', 'rb') as f:
    train_y = pickle.load(f)
with open(path+data_type+'train2_x_'+str(num_word)+'_'+normalized+erased_word+'.pickle', 'rb') as f:
    train2_x = pickle.load(f)
with open(path+data_type+'train2_y_'+str(num_word)+'_'+normalized+erased_word+'.pickle', 'rb') as f:
    train2_y = pickle.load(f)
with open(path+data_type+'test_x_'+str(num_word)+'_'+normalized+erased_word+'.pickle', 'rb') as f:
    test_x = pickle.load(f)
with open(path+data_type+'test_y_'+str(num_word)+'_'+normalized+erased_word+'.pickle', 'rb') as f:
    test_y = pickle.load(f)
with open(path+data_type+'test2_x_'+str(num_word)+'_'+normalized+erased_word+'.pickle', 'rb') as f:
    test2_x = pickle.load(f)
with open(path+data_type+'test2_y_'+str(num_word)+'_'+normalized+erased_word+'.pickle', 'rb') as f:
    test2_y = pickle.load(f)

# %%
# numpy 사용하여 float로 바꾸어주는 과정
import numpy as np
x_train = np.asarray(train_x).astype('float32')
y_train = np.asarray(train_y).astype('float32')
x_test = np.asarray(test_x).astype('float32')
y_test = np.asarray(test_y).astype('float32')

# %%
# DNN 학습 모델
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import optimizers
from tensorflow.keras import losses
from tensorflow.keras import metrics
#from tensorflow.keras.callbacks import EarlyStopping


#callbacks = [EarlyStopping(monitor='val_loss',patience = 20)]
model = models.Sequential()
n =len(x_train[0])
model.add(layers.Dense(first_layer,activation='relu'))#실제 쓸 단어갯수
model.add(layers.Dense(second_layer,activation='relu'))
model.add(layers.Dense(3,activation='softmax'))
model.compile(optimizer=optimizers.RMSprop(lr=0.001),loss = losses.categorical_crossentropy,metrics=[metrics.categorical_accuracy])

#hist = model.fit(x_train,y_train,epochs=ep,validation_data=(x_train2,y_train2),callbacks=callbacks,batch_size=ba, shuffle=True)
hist = model.fit(x_train,y_train,epochs=ep,validation_data=(x_test,y_test),batch_size=ba)
# Out:
# Epoch 1/60
# 10/10 [==============================] - 174s 17s/step - loss: 1.0906 - categorical_accuracy: 0.3668 - val_loss: 1.0878 - val_categorical_accuracy: 0.3816
# Epoch 2/60
# 10/10 [==============================] - 15s 2s/step - loss: 1.0731 - categorical_accuracy: 0.4205 - val_loss: 1.0815 - val_categorical_accuracy: 0.4112
# Epoch 3/60
# 10/10 [==============================] - 15s 2s/step - loss: 1.0709 - categorical_accuracy: 0.4446 - val_loss: 1.0638 - val_categorical_accuracy: 0.4278
# Epoch 4/60
# 10/10 [==============================] - 15s 2s/step - loss: 1.0217 - categorical_accuracy: 0.4566 - val_loss: 1.0925 - val_categorical_accuracy: 0.3865
# Epoch 5/60
# 10/10 [==============================] - 16s 2s/step - loss: 0.9987 - categorical_accuracy: 0.4966 - val_loss: 1.0488 - val_categorical_accuracy: 0.4557
# Epoch 6/60
# 10/10 [==============================] - 15s 2s/step - loss: 0.9662 - categorical_accuracy: 0.5300 - val_loss: 1.0489 - val_categorical_accuracy: 0.4572
# Epoch 7/60
# 10/10 [==============================] - 15s 2s/step - loss: 0.9479 - categorical_accuracy: 0.5540 - val_loss: 1.0516 - val_categorical_accuracy: 0.4592
# Epoch 8/60
# 10/10 [==============================] - 15s 2s/step - loss: 0.9071 - categorical_accuracy: 0.5857 - val_loss: 1.1121 - val_categorical_accuracy: 0.4505
# Epoch 9/60
# 10/10 [==============================] - 15s 2s/step - loss: 0.8814 - categorical_accuracy: 0.5792 - val_loss: 1.0598 - val_categorical_accuracy: 0.4449
# Epoch 10/60
# 10/10 [==============================] - 15s 2s/step - loss: 0.8510 - categorical_accuracy: 0.6129 - val_loss: 1.1776 - val_categorical_accuracy: 0.4589
# Epoch 11/60
# 10/10 [==============================] - 16s 2s/step - loss: 0.8211 - categorical_accuracy: 0.6319 - val_loss: 1.1180 - val_categorical_accuracy: 0.3941
# Epoch 12/60
# 10/10 [==============================] - 15s 2s/step - loss: 0.7953 - categorical_accuracy: 0.6439 - val_loss: 1.1343 - val_categorical_accuracy: 0.4761
# Epoch 13/60
# 10/10 [==============================] - 15s 2s/step - loss: 0.7452 - categorical_accuracy: 0.6798 - val_loss: 1.1258 - val_categorical_accuracy: 0.4709
# Epoch 14/60
# 10/10 [==============================] - 15s 2s/step - loss: 0.7431 - categorical_accuracy: 0.6598 - val_loss: 1.1642 - val_categorical_accuracy: 0.4402
# Epoch 15/60
# 10/10 [==============================] - 15s 2s/step - loss: 0.6834 - categorical_accuracy: 0.7053 - val_loss: 1.2280 - val_categorical_accuracy: 0.4419
# Epoch 16/60
# 10/10 [==============================] - 15s 1s/step - loss: 0.7028 - categorical_accuracy: 0.6976 - val_loss: 1.1042 - val_categorical_accuracy: 0.4941
# Epoch 17/60
# 10/10 [==============================] - 15s 2s/step - loss: 0.6410 - categorical_accuracy: 0.7341 - val_loss: 1.2171 - val_categorical_accuracy: 0.4353
# Epoch 18/60
# 10/10 [==============================] - 15s 2s/step - loss: 0.5942 - categorical_accuracy: 0.7575 - val_loss: 1.4215 - val_categorical_accuracy: 0.4749
# Epoch 19/60
# 10/10 [==============================] - 15s 1s/step - loss: 0.6022 - categorical_accuracy: 0.7445 - val_loss: 1.1510 - val_categorical_accuracy: 0.4805
# Epoch 20/60
# 10/10 [==============================] - 15s 2s/step - loss: 0.5273 - categorical_accuracy: 0.7912 - val_loss: 1.2672 - val_categorical_accuracy: 0.4823
# Epoch 21/60
# 10/10 [==============================] - 16s 2s/step - loss: 0.5574 - categorical_accuracy: 0.7714 - val_loss: 1.1407 - val_categorical_accuracy: 0.5029
# Epoch 22/60
# 10/10 [==============================] - 15s 2s/step - loss: 0.4833 - categorical_accuracy: 0.8230 - val_loss: 1.4263 - val_categorical_accuracy: 0.4778
# Epoch 23/60
# 10/10 [==============================] - 16s 2s/step - loss: 0.4169 - categorical_accuracy: 0.8442 - val_loss: 1.9938 - val_categorical_accuracy: 0.4683
# Epoch 24/60
# 10/10 [==============================] - 17s 2s/step - loss: 0.4593 - categorical_accuracy: 0.8258 - val_loss: 1.3239 - val_categorical_accuracy: 0.5061
# Epoch 25/60
# 10/10 [==============================] - 15s 2s/step - loss: 0.4374 - categorical_accuracy: 0.8206 - val_loss: 1.1942 - val_categorical_accuracy: 0.4944
# Epoch 26/60
# 10/10 [==============================] - 15s 2s/step - loss: 0.3430 - categorical_accuracy: 0.8803 - val_loss: 1.6534 - val_categorical_accuracy: 0.4417
# Epoch 27/60
# 10/10 [==============================] - 15s 2s/step - loss: 0.3634 - categorical_accuracy: 0.8644 - val_loss: 1.6666 - val_categorical_accuracy: 0.4820
# Epoch 28/60
# 10/10 [==============================] - 16s 2s/step - loss: 0.3547 - categorical_accuracy: 0.8641 - val_loss: 1.5877 - val_categorical_accuracy: 0.5067
# Epoch 29/60
# 10/10 [==============================] - 15s 2s/step - loss: 0.2751 - categorical_accuracy: 0.9014 - val_loss: 1.5132 - val_categorical_accuracy: 0.5138
# Epoch 30/60
# 10/10 [==============================] - 15s 2s/step - loss: 0.3613 - categorical_accuracy: 0.8549 - val_loss: 1.3375 - val_categorical_accuracy: 0.5096
# Epoch 31/60
# 10/10 [==============================] - 15s 2s/step - loss: 0.2692 - categorical_accuracy: 0.8943 - val_loss: 1.9619 - val_categorical_accuracy: 0.4185
# Epoch 32/60
# 10/10 [==============================] - 15s 2s/step - loss: 0.2558 - categorical_accuracy: 0.9194 - val_loss: 1.5660 - val_categorical_accuracy: 0.5153
# Epoch 33/60
# 10/10 [==============================] - 15s 2s/step - loss: 0.3473 - categorical_accuracy: 0.8454 - val_loss: 1.2881 - val_categorical_accuracy: 0.5057
# Epoch 34/60
# 10/10 [==============================] - 15s 2s/step - loss: 0.1383 - categorical_accuracy: 0.9656 - val_loss: 1.6717 - val_categorical_accuracy: 0.5143
# Epoch 35/60
# 10/10 [==============================] - 15s 2s/step - loss: 0.3249 - categorical_accuracy: 0.8792 - val_loss: 1.4337 - val_categorical_accuracy: 0.5239
# Epoch 36/60
# 10/10 [==============================] - 13s 1s/step - loss: 0.1077 - categorical_accuracy: 0.9715 - val_loss: 1.8097 - val_categorical_accuracy: 0.5212
# Epoch 37/60
# 10/10 [==============================] - 11s 1s/step - loss: 0.7512 - categorical_accuracy: 0.7849 - val_loss: 1.3040 - val_categorical_accuracy: 0.5172
# Epoch 38/60
# 10/10 [==============================] - 11s 1s/step - loss: 0.1238 - categorical_accuracy: 0.9729 - val_loss: 1.5912 - val_categorical_accuracy: 0.5209
# Epoch 39/60
# 10/10 [==============================] - 11s 1s/step - loss: 0.0913 - categorical_accuracy: 0.9732 - val_loss: 1.9225 - val_categorical_accuracy: 0.5179
# Epoch 40/60
# 10/10 [==============================] - 11s 1s/step - loss: 0.2524 - categorical_accuracy: 0.8996 - val_loss: 1.5410 - val_categorical_accuracy: 0.5190
# Epoch 41/60
# 10/10 [==============================] - 11s 1s/step - loss: 0.0842 - categorical_accuracy: 0.9780 - val_loss: 1.8642 - val_categorical_accuracy: 0.5200
# Epoch 42/60
# 10/10 [==============================] - 11s 1s/step - loss: 0.4921 - categorical_accuracy: 0.8189 - val_loss: 1.3892 - val_categorical_accuracy: 0.5263
# Epoch 43/60
# 10/10 [==============================] - 8s 798ms/step - loss: 0.0938 - categorical_accuracy: 0.9789 - val_loss: 1.6663 - val_categorical_accuracy: 0.5227
# Epoch 44/60
# 10/10 [==============================] - 6s 649ms/step - loss: 0.0707 - categorical_accuracy: 0.9787 - val_loss: 1.8654 - val_categorical_accuracy: 0.5162
# Epoch 45/60
# 10/10 [==============================] - 7s 722ms/step - loss: 0.2714 - categorical_accuracy: 0.8895 - val_loss: 1.5758 - val_categorical_accuracy: 0.5234
# Epoch 46/60
# 10/10 [==============================] - 7s 708ms/step - loss: 0.0669 - categorical_accuracy: 0.9826 - val_loss: 1.8477 - val_categorical_accuracy: 0.5226
# Epoch 47/60
# 10/10 [==============================] - 7s 731ms/step - loss: 0.0653 - categorical_accuracy: 0.9767 - val_loss: 1.9923 - val_categorical_accuracy: 0.5099
# Epoch 48/60
# 10/10 [==============================] - 7s 715ms/step - loss: 0.8230 - categorical_accuracy: 0.7961 - val_loss: 1.5636 - val_categorical_accuracy: 0.5212
# Epoch 49/60
# 10/10 [==============================] - 7s 683ms/step - loss: 0.0679 - categorical_accuracy: 0.9841 - val_loss: 1.7626 - val_categorical_accuracy: 0.5214
# Epoch 50/60
# 10/10 [==============================] - 7s 749ms/step - loss: 0.0540 - categorical_accuracy: 0.9831 - val_loss: 1.9090 - val_categorical_accuracy: 0.5195
# Epoch 51/60
# 10/10 [==============================] - 9s 855ms/step - loss: 0.0575 - categorical_accuracy: 0.9776 - val_loss: 2.2261 - val_categorical_accuracy: 0.4885
# Epoch 52/60
# 10/10 [==============================] - 7s 668ms/step - loss: 0.2645 - categorical_accuracy: 0.8959 - val_loss: 1.6932 - val_categorical_accuracy: 0.5234
# Epoch 53/60
# 10/10 [==============================] - 6s 620ms/step - loss: 0.0507 - categorical_accuracy: 0.9847 - val_loss: 1.9502 - val_categorical_accuracy: 0.5173
# Epoch 54/60
# 10/10 [==============================] - 7s 727ms/step - loss: 0.2383 - categorical_accuracy: 0.9468 - val_loss: 2.3494 - val_categorical_accuracy: 0.4131
# Epoch 55/60
# 10/10 [==============================] - 8s 832ms/step - loss: 0.1215 - categorical_accuracy: 0.9582 - val_loss: 1.7593 - val_categorical_accuracy: 0.5239
# Epoch 56/60
# 10/10 [==============================] - 7s 734ms/step - loss: 0.0493 - categorical_accuracy: 0.9824 - val_loss: 2.0973 - val_categorical_accuracy: 0.4919
# Epoch 57/60
# 10/10 [==============================] - 7s 690ms/step - loss: 0.0572 - categorical_accuracy: 0.9804 - val_loss: 2.1125 - val_categorical_accuracy: 0.5211
# Epoch 58/60
# 10/10 [==============================] - 7s 736ms/step - loss: 0.0511 - categorical_accuracy: 0.9794 - val_loss: 3.2152 - val_categorical_accuracy: 0.4325
# Epoch 59/60
# 10/10 [==============================] - 7s 684ms/step - loss: 0.5938 - categorical_accuracy: 0.8839 - val_loss: 1.8095 - val_categorical_accuracy: 0.5246
# Epoch 60/60
# 10/10 [==============================] - 7s 710ms/step - loss: 0.0414 - categorical_accuracy: 0.9854 - val_loss: 2.0005 - val_categorical_accuracy: 0.5216

# %%
# 모델의 예측값을 튜플로 반환하는 함수
def predict(x):
    data = np.expand_dims(np.asarray(x).astype('float32'),axis=0)
    result = model.predict(data)
    return tuple(result[0])

# %%
# 모든 날짜의 예측값들을 합치기 위한 튜플의 합 함수
def sum_tuple(a,b):
    return (a[0]+b[0],a[1]+b[1],a[2]+b[2])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

fig, acc_ax = plt.subplots()

loss_ax = acc_ax.twinx()

loss_ax.plot(hist.history['loss'], 'y', label='train loss')
loss_ax.plot(hist.history['val_loss'], 'r', label='val loss')

acc_ax.plot(hist.history['categorical_accuracy'], 'b', label='train acc')
acc_ax.plot(hist.history['val_categorical_accuracy'], 'g', label='val acc')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuray')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()

# %%
# Test set에 대한 예측 및 예측 정확도의 계산
import re

count = 0
sum_dic = {}
for data in train2_x:
    result = predict(data[0])
    if data[1] in sum_dic:
        sum_dic[data[1]] = sum_tuple(sum_dic[data[1]],result)
    else:
        sum_dic[data[1]] = result
    
for date in sum_dic:
    real = train2_y[date]
    value = sum_dic[date].index(max(sum_dic[date]))
    value -= 1
    if real == value:
        count = count + 1
train_score = count / len(sum_dic)

count = 0
sum_dic = {}
for data in test2_x:
    result = predict(data[0])
    if data[1] in sum_dic:
        sum_dic[data[1]] = sum_tuple(sum_dic[data[1]],result)
    else:
        sum_dic[data[1]] = result
    
for date in sum_dic:
    real = test2_y[date]
    value = sum_dic[date].index(max(sum_dic[date]))
    value -= 1
    if real == value:
        count = count + 1
test_score = count / len(sum_dic)

# %%
print('단어 갯수 : '+num_word)
print('모델 레이어 및 노드 수 : ','첫 번째 레이어 - relu,',first_layer,', 두 번째 레이어 - relu,',second_layer)
print('epochs : ',ep,', batch_size : ', ba)
print('train 데이터 정확도 : ', train_score)
print('test 데이터 정확도 : ', test_score)
# Out:
# 단어 갯수 : 6000
# 모델 레이어 및 노드 수 :  첫 번째 레이어 - relu, 3000 , 두 번째 레이어 - relu, 1000
# epochs :  60 , batch_size :  1000
# train 데이터 정확도 :  1.0
# test 데이터 정확도 :  0.7835294117647059
