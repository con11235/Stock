# %%
# 사용할 데이터의 형태
data_type = '8'      # '1' : summarize X,개별 기사   '2' : summarize X,날짜별 기사
                    # '3' : summarize O,개별 기사   '4' : summarize O,날짜별 기사
normalized = 'done' # 'done' : 데이터 행별 normalize한 데이터     'not' : 데이터 행별 normalize 안한 데이터
erased_word = 'J'    # 제거된 단어 형태
num_word = '6000'   # 사용할 단어 수

# 돌려볼 모델의 구조
first_layer = 3000   # 모델의 첫 번째 레이어 수
second_layer = 1000  # 모델의 두 번째 레이어 수
ep = 60            # 모델의 에포크 수
ba = 1000            # 모델의 배치 사이즈

# %%
# 생성된 training, test의 x,y값을 pickle의 형태로 저장
import pickle
import os
path = os.getcwd()+'/pickles/'
if erased_word != '':
    erased_word = '_'+erased_word
with open(path+data_type+'train_x_'+str(num_word)+'_'+normalized+erased_word+'.pickle', 'rb') as f:
    train_x = pickle.load(f)
with open(path+data_type+'train_y_'+str(num_word)+'_'+normalized+erased_word+'.pickle', 'rb') as f:
    train_y = pickle.load(f)
with open(path+data_type+'train2_x_'+str(num_word)+'_'+normalized+erased_word+'.pickle', 'rb') as f:
    train2_x = pickle.load(f)
with open(path+data_type+'train2_y_'+str(num_word)+'_'+normalized+erased_word+'.pickle', 'rb') as f:
    train2_y = pickle.load(f)
with open(path+data_type+'test_x_'+str(num_word)+'_'+normalized+erased_word+'.pickle', 'rb') as f:
    test_x = pickle.load(f)
with open(path+data_type+'test_y_'+str(num_word)+'_'+normalized+erased_word+'.pickle', 'rb') as f:
    test_y = pickle.load(f)
with open(path+data_type+'test2_x_'+str(num_word)+'_'+normalized+erased_word+'.pickle', 'rb') as f:
    test2_x = pickle.load(f)
with open(path+data_type+'test2_y_'+str(num_word)+'_'+normalized+erased_word+'.pickle', 'rb') as f:
    test2_y = pickle.load(f)

# %%
# numpy 사용하여 float로 바꾸어주는 과정
import numpy as np
x_train = np.asarray(train_x).astype('float32')
y_train = np.asarray(train_y).astype('float32')
x_test = np.asarray(test_x).astype('float32')
y_test = np.asarray(test_y).astype('float32')

# %%
# DNN 학습 모델
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import optimizers
from tensorflow.keras import losses
from tensorflow.keras import metrics
#from tensorflow.keras.callbacks import EarlyStopping


#callbacks = [EarlyStopping(monitor='val_loss',patience = 20)]
model = models.Sequential()
n =len(x_train[0])
model.add(layers.Dense(first_layer,activation='relu'))#실제 쓸 단어갯수
model.add(layers.Dense(second_layer,activation='relu'))
model.add(layers.Dense(3,activation='softmax'))
model.compile(optimizer=optimizers.RMSprop(lr=0.001),loss = losses.categorical_crossentropy,metrics=[metrics.categorical_accuracy])

#hist = model.fit(x_train,y_train,epochs=ep,validation_data=(x_train2,y_train2),callbacks=callbacks,batch_size=ba, shuffle=True)
hist = model.fit(x_train,y_train,epochs=ep,validation_data=(x_test,y_test),batch_size=ba)
# Out:
# Epoch 1/60
# 10/10 [==============================] - 9s 920ms/step - loss: 1.0898 - categorical_accuracy: 0.3826 - val_loss: 1.0891 - val_categorical_accuracy: 0.3749
# Epoch 2/60
# 10/10 [==============================] - 7s 740ms/step - loss: 1.0738 - categorical_accuracy: 0.3950 - val_loss: 1.0720 - val_categorical_accuracy: 0.3894
# Epoch 3/60
# 10/10 [==============================] - 8s 781ms/step - loss: 1.0435 - categorical_accuracy: 0.4332 - val_loss: 1.0930 - val_categorical_accuracy: 0.3826
# Epoch 4/60
# 10/10 [==============================] - 8s 776ms/step - loss: 1.0165 - categorical_accuracy: 0.4499 - val_loss: 1.0645 - val_categorical_accuracy: 0.4109
# Epoch 5/60
# 10/10 [==============================] - 8s 775ms/step - loss: 0.9739 - categorical_accuracy: 0.5257 - val_loss: 1.1331 - val_categorical_accuracy: 0.3959
# Epoch 6/60
# 10/10 [==============================] - 7s 729ms/step - loss: 0.9390 - categorical_accuracy: 0.5535 - val_loss: 1.0775 - val_categorical_accuracy: 0.3929
# Epoch 7/60
# 10/10 [==============================] - 7s 693ms/step - loss: 0.8830 - categorical_accuracy: 0.5862 - val_loss: 1.0867 - val_categorical_accuracy: 0.4323
# Epoch 8/60
# 10/10 [==============================] - 7s 678ms/step - loss: 0.8660 - categorical_accuracy: 0.5949 - val_loss: 1.1286 - val_categorical_accuracy: 0.4059
# Epoch 9/60
# 10/10 [==============================] - 7s 686ms/step - loss: 0.8235 - categorical_accuracy: 0.6363 - val_loss: 1.0741 - val_categorical_accuracy: 0.4459
# Epoch 10/60
# 10/10 [==============================] - 7s 682ms/step - loss: 0.7857 - categorical_accuracy: 0.6497 - val_loss: 1.1036 - val_categorical_accuracy: 0.4759
# Epoch 11/60
# 10/10 [==============================] - 7s 685ms/step - loss: 0.7279 - categorical_accuracy: 0.6782 - val_loss: 1.1191 - val_categorical_accuracy: 0.4875
# Epoch 12/60
# 10/10 [==============================] - 7s 690ms/step - loss: 0.7124 - categorical_accuracy: 0.7050 - val_loss: 1.0918 - val_categorical_accuracy: 0.4921
# Epoch 13/60
# 10/10 [==============================] - 7s 738ms/step - loss: 0.6851 - categorical_accuracy: 0.7071 - val_loss: 1.0918 - val_categorical_accuracy: 0.4978
# Epoch 14/60
# 10/10 [==============================] - 7s 698ms/step - loss: 0.6164 - categorical_accuracy: 0.7435 - val_loss: 1.2126 - val_categorical_accuracy: 0.4899
# Epoch 15/60
# 10/10 [==============================] - 6s 640ms/step - loss: 0.5754 - categorical_accuracy: 0.7658 - val_loss: 1.1119 - val_categorical_accuracy: 0.4874
# Epoch 16/60
# 10/10 [==============================] - 6s 634ms/step - loss: 0.5610 - categorical_accuracy: 0.7647 - val_loss: 1.2374 - val_categorical_accuracy: 0.5003
# Epoch 17/60
# 10/10 [==============================] - 6s 628ms/step - loss: 0.5107 - categorical_accuracy: 0.7933 - val_loss: 1.3128 - val_categorical_accuracy: 0.4353
# Epoch 18/60
# 10/10 [==============================] - 6s 624ms/step - loss: 0.4640 - categorical_accuracy: 0.8245 - val_loss: 1.5834 - val_categorical_accuracy: 0.4315
# Epoch 19/60
# 10/10 [==============================] - 6s 625ms/step - loss: 0.4480 - categorical_accuracy: 0.8243 - val_loss: 1.3596 - val_categorical_accuracy: 0.5076
# Epoch 20/60
# 10/10 [==============================] - 6s 622ms/step - loss: 0.4541 - categorical_accuracy: 0.8133 - val_loss: 1.2135 - val_categorical_accuracy: 0.5037
# Epoch 21/60
# 10/10 [==============================] - 6s 642ms/step - loss: 0.4162 - categorical_accuracy: 0.8320 - val_loss: 1.4026 - val_categorical_accuracy: 0.5118
# Epoch 22/60
# 10/10 [==============================] - 7s 651ms/step - loss: 0.2867 - categorical_accuracy: 0.9070 - val_loss: 2.2714 - val_categorical_accuracy: 0.4249
# Epoch 23/60
# 10/10 [==============================] - 7s 688ms/step - loss: 0.3869 - categorical_accuracy: 0.8700 - val_loss: 1.4020 - val_categorical_accuracy: 0.5140
# Epoch 24/60
# 10/10 [==============================] - 7s 708ms/step - loss: 0.3650 - categorical_accuracy: 0.8699 - val_loss: 1.5165 - val_categorical_accuracy: 0.4875
# Epoch 25/60
# 10/10 [==============================] - 7s 669ms/step - loss: 0.2818 - categorical_accuracy: 0.9029 - val_loss: 1.3083 - val_categorical_accuracy: 0.4998
# Epoch 26/60
# 10/10 [==============================] - 7s 722ms/step - loss: 0.1827 - categorical_accuracy: 0.9551 - val_loss: 1.8210 - val_categorical_accuracy: 0.5000
# Epoch 27/60
# 10/10 [==============================] - 7s 671ms/step - loss: 0.3363 - categorical_accuracy: 0.8608 - val_loss: 1.4794 - val_categorical_accuracy: 0.5182
# Epoch 28/60
# 10/10 [==============================] - 7s 735ms/step - loss: 0.1753 - categorical_accuracy: 0.9409 - val_loss: 2.3745 - val_categorical_accuracy: 0.4749
# Epoch 29/60
# 10/10 [==============================] - 7s 724ms/step - loss: 0.2729 - categorical_accuracy: 0.8921 - val_loss: 1.5757 - val_categorical_accuracy: 0.5195
# Epoch 30/60
# 10/10 [==============================] - 7s 693ms/step - loss: 0.1164 - categorical_accuracy: 0.9646 - val_loss: 2.9735 - val_categorical_accuracy: 0.4286
# Epoch 31/60
# 10/10 [==============================] - 7s 684ms/step - loss: 0.4803 - categorical_accuracy: 0.8448 - val_loss: 1.5580 - val_categorical_accuracy: 0.5221
# Epoch 32/60
# 10/10 [==============================] - 7s 686ms/step - loss: 0.0984 - categorical_accuracy: 0.9728 - val_loss: 1.9107 - val_categorical_accuracy: 0.5227
# Epoch 33/60
# 10/10 [==============================] - 8s 755ms/step - loss: 0.1735 - categorical_accuracy: 0.9336 - val_loss: 1.7766 - val_categorical_accuracy: 0.5253
# Epoch 34/60
# 10/10 [==============================] - 7s 733ms/step - loss: 0.3239 - categorical_accuracy: 0.8888 - val_loss: 1.5190 - val_categorical_accuracy: 0.4791
# Epoch 35/60
# 10/10 [==============================] - 7s 686ms/step - loss: 0.0978 - categorical_accuracy: 0.9744 - val_loss: 1.7193 - val_categorical_accuracy: 0.5234
# Epoch 36/60
# 10/10 [==============================] - 7s 678ms/step - loss: 0.0972 - categorical_accuracy: 0.9652 - val_loss: 3.0798 - val_categorical_accuracy: 0.4816
# Epoch 37/60
# 10/10 [==============================] - 7s 684ms/step - loss: 0.2894 - categorical_accuracy: 0.8956 - val_loss: 1.6604 - val_categorical_accuracy: 0.5264
# Epoch 38/60
# 10/10 [==============================] - 7s 720ms/step - loss: 0.0636 - categorical_accuracy: 0.9817 - val_loss: 1.8615 - val_categorical_accuracy: 0.5232
# Epoch 39/60
# 10/10 [==============================] - 8s 803ms/step - loss: 0.2915 - categorical_accuracy: 0.8995 - val_loss: 3.0503 - val_categorical_accuracy: 0.3331
# Epoch 40/60
# 10/10 [==============================] - 8s 771ms/step - loss: 0.2413 - categorical_accuracy: 0.9258 - val_loss: 1.7445 - val_categorical_accuracy: 0.5236
# Epoch 41/60
# 10/10 [==============================] - 8s 769ms/step - loss: 0.0575 - categorical_accuracy: 0.9825 - val_loss: 1.9382 - val_categorical_accuracy: 0.5211
# Epoch 42/60
# 10/10 [==============================] - 7s 717ms/step - loss: 0.0550 - categorical_accuracy: 0.9801 - val_loss: 2.1639 - val_categorical_accuracy: 0.5066
# Epoch 43/60
# 10/10 [==============================] - 7s 688ms/step - loss: 0.3157 - categorical_accuracy: 0.8977 - val_loss: 1.7076 - val_categorical_accuracy: 0.5229
# Epoch 44/60
# 10/10 [==============================] - 7s 701ms/step - loss: 0.0526 - categorical_accuracy: 0.9834 - val_loss: 1.8705 - val_categorical_accuracy: 0.5229
# Epoch 45/60
# 10/10 [==============================] - 7s 747ms/step - loss: 0.0698 - categorical_accuracy: 0.9748 - val_loss: 2.7747 - val_categorical_accuracy: 0.4057
# Epoch 46/60
# 10/10 [==============================] - 8s 762ms/step - loss: 0.2459 - categorical_accuracy: 0.9182 - val_loss: 1.8014 - val_categorical_accuracy: 0.5259
# Epoch 47/60
# 10/10 [==============================] - 7s 708ms/step - loss: 0.0452 - categorical_accuracy: 0.9852 - val_loss: 1.9923 - val_categorical_accuracy: 0.5248
# Epoch 48/60
# 10/10 [==============================] - 7s 704ms/step - loss: 0.0424 - categorical_accuracy: 0.9832 - val_loss: 2.1675 - val_categorical_accuracy: 0.5170
# Epoch 49/60
# 10/10 [==============================] - 7s 703ms/step - loss: 0.8956 - categorical_accuracy: 0.7942 - val_loss: 1.8624 - val_categorical_accuracy: 0.5116
# Epoch 50/60
# 10/10 [==============================] - 8s 762ms/step - loss: 0.0455 - categorical_accuracy: 0.9853 - val_loss: 1.9392 - val_categorical_accuracy: 0.5221
# Epoch 51/60
# 10/10 [==============================] - 8s 761ms/step - loss: 0.0387 - categorical_accuracy: 0.9856 - val_loss: 2.0593 - val_categorical_accuracy: 0.5224
# Epoch 52/60
# 10/10 [==============================] - 7s 731ms/step - loss: 0.0374 - categorical_accuracy: 0.9846 - val_loss: 2.1274 - val_categorical_accuracy: 0.5197
# Epoch 53/60
# 10/10 [==============================] - 7s 699ms/step - loss: 0.0393 - categorical_accuracy: 0.9840 - val_loss: 2.4630 - val_categorical_accuracy: 0.4710
# Epoch 54/60
# 10/10 [==============================] - 7s 706ms/step - loss: 0.4713 - categorical_accuracy: 0.8432 - val_loss: 1.8596 - val_categorical_accuracy: 0.5227
# Epoch 55/60
# 10/10 [==============================] - 8s 759ms/step - loss: 0.0396 - categorical_accuracy: 0.9871 - val_loss: 1.9944 - val_categorical_accuracy: 0.5226
# Epoch 56/60
# 10/10 [==============================] - 7s 741ms/step - loss: 0.0340 - categorical_accuracy: 0.9866 - val_loss: 2.1319 - val_categorical_accuracy: 0.5221
# Epoch 57/60
# 10/10 [==============================] - 7s 740ms/step - loss: 0.0345 - categorical_accuracy: 0.9855 - val_loss: 2.3227 - val_categorical_accuracy: 0.5148
# Epoch 58/60
# 10/10 [==============================] - 7s 722ms/step - loss: 0.4073 - categorical_accuracy: 0.8642 - val_loss: 1.7954 - val_categorical_accuracy: 0.5243
# Epoch 59/60
# 10/10 [==============================] - 7s 694ms/step - loss: 0.0366 - categorical_accuracy: 0.9866 - val_loss: 1.9762 - val_categorical_accuracy: 0.5226
# Epoch 60/60
# 10/10 [==============================] - 7s 726ms/step - loss: 0.0321 - categorical_accuracy: 0.9865 - val_loss: 2.1304 - val_categorical_accuracy: 0.5261

# %%
# 모델의 예측값을 튜플로 반환하는 함수
def predict(x):
    data = np.expand_dims(np.asarray(x).astype('float32'),axis=0)
    result = model.predict(data)
    return tuple(result[0])

# %%
# 모든 날짜의 예측값들을 합치기 위한 튜플의 합 함수
def sum_tuple(a,b):
    return (a[0]+b[0],a[1]+b[1],a[2]+b[2])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

fig, acc_ax = plt.subplots()

loss_ax = acc_ax.twinx()

loss_ax.plot(hist.history['loss'], 'y', label='train loss')
loss_ax.plot(hist.history['val_loss'], 'r', label='val loss')

acc_ax.plot(hist.history['categorical_accuracy'], 'b', label='train acc')
acc_ax.plot(hist.history['val_categorical_accuracy'], 'g', label='val acc')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuray')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()

# %%
# Test set에 대한 예측 및 예측 정확도의 계산
import re

count = 0
sum_dic = {}
for data in train2_x:
    result = predict(data[0])
    if data[1] in sum_dic:
        sum_dic[data[1]] = sum_tuple(sum_dic[data[1]],result)
    else:
        sum_dic[data[1]] = result
    
for date in sum_dic:
    real = train2_y[date]
    value = sum_dic[date].index(max(sum_dic[date]))
    value -= 1
    if real == value:
        count = count + 1
train_score = count / len(sum_dic)

count = 0
sum_dic = {}
for data in test2_x:
    result = predict(data[0])
    if data[1] in sum_dic:
        sum_dic[data[1]] = sum_tuple(sum_dic[data[1]],result)
    else:
        sum_dic[data[1]] = result
    
for date in sum_dic:
    real = test2_y[date]
    value = sum_dic[date].index(max(sum_dic[date]))
    value -= 1
    if real == value:
        count = count + 1
test_score = count / len(sum_dic)

# %%
print('단어 갯수 : '+num_word)
print('모델 레이어 및 노드 수 : ','첫 번째 레이어 - relu,',first_layer,', 두 번째 레이어 - relu,',second_layer)
print('epochs : ',ep,', batch_size : ', ba)
print('train 데이터 정확도 : ', train_score)
print('test 데이터 정확도 : ', test_score)
# Out:
# 단어 갯수 : 6000
# 모델 레이어 및 노드 수 :  첫 번째 레이어 - relu, 3000 , 두 번째 레이어 - relu, 1000
# epochs :  100 , batch_size :  1000
# train 데이터 정확도 :  1.0
# test 데이터 정확도 :  0.7623529411764706

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

fig, acc_ax = plt.subplots()

loss_ax = acc_ax.twinx()

loss_ax.plot(hist.history['loss'], 'y', label='train loss')
loss_ax.plot(hist.history['val_loss'], 'r', label='val loss')

acc_ax.plot(hist.history['categorical_accuracy'], 'b', label='train acc')
acc_ax.plot(hist.history['val_categorical_accuracy'], 'g', label='val acc')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuray')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()

# %%
print('단어 갯수 : '+num_word)
print('모델 레이어 및 노드 수 : ','첫 번째 레이어 - relu,',first_layer,', 두 번째 레이어 - relu,',second_layer)
print('epochs : ',ep,', batch_size : ', ba)
print('train 데이터 정확도 : ', train_score)
print('test 데이터 정확도 : ', test_score)
# Out:
# 단어 갯수 : 6000
# 모델 레이어 및 노드 수 :  첫 번째 레이어 - relu, 3000 , 두 번째 레이어 - relu, 1000
# epochs :  60 , batch_size :  1000
# train 데이터 정확도 :  1.0
# test 데이터 정확도 :  0.7764705882352941
