# %%
# 사용할 데이터의 형태
data_type = '8'      # '1' : summarize X,개별 기사   '2' : summarize X,날짜별 기사
                    # '3' : summarize O,개별 기사   '4' : summarize O,날짜별 기사
normalized = 'done' # 'done' : 데이터 행별 normalize한 데이터     'not' : 데이터 행별 normalize 안한 데이터
erased_word = 'N'    # 제거된 단어 형태
num_word = '6000'   # 사용할 단어 수

# 돌려볼 모델의 구조
first_layer = 3000   # 모델의 첫 번째 레이어 수
second_layer = 1000  # 모델의 두 번째 레이어 수
ep = 60             # 모델의 에포크 수
ba = 1000            # 모델의 배치 사이즈

# %%
# 생성된 training, test의 x,y값을 pickle의 형태로 저장
import pickle
import os
path = os.getcwd()+'/pickles/'
if erased_word != '':
    erased_word = '_'+erased_word
with open(path+data_type+'train_x_'+str(num_word)+'_'+normalized+erased_word+'.pickle', 'rb') as f:
    train_x = pickle.load(f)
with open(path+data_type+'train_y_'+str(num_word)+'_'+normalized+erased_word+'.pickle', 'rb') as f:
    train_y = pickle.load(f)
with open(path+data_type+'train2_x_'+str(num_word)+'_'+normalized+erased_word+'.pickle', 'rb') as f:
    train2_x = pickle.load(f)
with open(path+data_type+'train2_y_'+str(num_word)+'_'+normalized+erased_word+'.pickle', 'rb') as f:
    train2_y = pickle.load(f)
with open(path+data_type+'test_x_'+str(num_word)+'_'+normalized+erased_word+'.pickle', 'rb') as f:
    test_x = pickle.load(f)
with open(path+data_type+'test_y_'+str(num_word)+'_'+normalized+erased_word+'.pickle', 'rb') as f:
    test_y = pickle.load(f)
with open(path+data_type+'test2_x_'+str(num_word)+'_'+normalized+erased_word+'.pickle', 'rb') as f:
    test2_x = pickle.load(f)
with open(path+data_type+'test2_y_'+str(num_word)+'_'+normalized+erased_word+'.pickle', 'rb') as f:
    test2_y = pickle.load(f)

# %%
# numpy 사용하여 float로 바꾸어주는 과정
import numpy as np
x_train = np.asarray(train_x).astype('float32')
y_train = np.asarray(train_y).astype('float32')
x_test = np.asarray(test_x).astype('float32')
y_test = np.asarray(test_y).astype('float32')

# %%
# DNN 학습 모델
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import optimizers
from tensorflow.keras import losses
from tensorflow.keras import metrics
#from tensorflow.keras.callbacks import EarlyStopping


#callbacks = [EarlyStopping(monitor='val_loss',patience = 20)]
model = models.Sequential()
n =len(x_train[0])
model.add(layers.Dense(first_layer,activation='relu'))#실제 쓸 단어갯수
model.add(layers.Dense(second_layer,activation='relu'))
model.add(layers.Dense(3,activation='softmax'))
model.compile(optimizer=optimizers.RMSprop(lr=0.001),loss = losses.categorical_crossentropy,metrics=[metrics.categorical_accuracy])

#hist = model.fit(x_train,y_train,epochs=ep,validation_data=(x_train2,y_train2),callbacks=callbacks,batch_size=ba, shuffle=True)
hist = model.fit(x_train,y_train,epochs=ep,validation_data=(x_test,y_test),batch_size=ba)
# Out:
# Epoch 1/60
# 10/10 [==============================] - 107s 11s/step - loss: 1.0909 - categorical_accuracy: 0.3660 - val_loss: 1.0860 - val_categorical_accuracy: 0.3969
# Epoch 2/60
# 10/10 [==============================] - 12s 1s/step - loss: 1.0753 - categorical_accuracy: 0.4001 - val_loss: 1.1022 - val_categorical_accuracy: 0.3816
# Epoch 3/60
# 10/10 [==============================] - 11s 1s/step - loss: 1.0628 - categorical_accuracy: 0.4185 - val_loss: 1.0821 - val_categorical_accuracy: 0.3953
# Epoch 4/60
# 10/10 [==============================] - 11s 1s/step - loss: 1.0359 - categorical_accuracy: 0.4549 - val_loss: 1.0620 - val_categorical_accuracy: 0.4306
# Epoch 5/60
# 10/10 [==============================] - 14s 1s/step - loss: 1.0089 - categorical_accuracy: 0.4894 - val_loss: 1.0571 - val_categorical_accuracy: 0.4375
# Epoch 6/60
# 10/10 [==============================] - 14s 1s/step - loss: 0.9808 - categorical_accuracy: 0.5070 - val_loss: 1.1022 - val_categorical_accuracy: 0.4173
# Epoch 7/60
# 10/10 [==============================] - 12s 1s/step - loss: 0.9549 - categorical_accuracy: 0.5339 - val_loss: 1.0838 - val_categorical_accuracy: 0.4395
# Epoch 8/60
# 10/10 [==============================] - 11s 1s/step - loss: 0.9134 - categorical_accuracy: 0.5606 - val_loss: 1.1348 - val_categorical_accuracy: 0.4331
# Epoch 9/60
# 10/10 [==============================] - 11s 1s/step - loss: 0.8911 - categorical_accuracy: 0.5704 - val_loss: 1.1217 - val_categorical_accuracy: 0.4490
# Epoch 10/60
# 10/10 [==============================] - 11s 1s/step - loss: 0.8636 - categorical_accuracy: 0.6001 - val_loss: 1.1195 - val_categorical_accuracy: 0.4079
# Epoch 11/60
# 10/10 [==============================] - 11s 1s/step - loss: 0.8396 - categorical_accuracy: 0.6199 - val_loss: 1.1145 - val_categorical_accuracy: 0.4340
# Epoch 12/60
# 10/10 [==============================] - 11s 1s/step - loss: 0.7908 - categorical_accuracy: 0.6510 - val_loss: 1.0919 - val_categorical_accuracy: 0.4624
# Epoch 13/60
# 10/10 [==============================] - 10s 1s/step - loss: 0.7500 - categorical_accuracy: 0.6656 - val_loss: 1.1252 - val_categorical_accuracy: 0.4387
# Epoch 14/60
# 10/10 [==============================] - 10s 1s/step - loss: 0.7503 - categorical_accuracy: 0.6667 - val_loss: 1.1966 - val_categorical_accuracy: 0.4685
# Epoch 15/60
# 10/10 [==============================] - 11s 1s/step - loss: 0.6893 - categorical_accuracy: 0.7039 - val_loss: 1.1979 - val_categorical_accuracy: 0.4116
# Epoch 16/60
# 10/10 [==============================] - 10s 1s/step - loss: 0.6910 - categorical_accuracy: 0.7118 - val_loss: 1.2546 - val_categorical_accuracy: 0.4080
# Epoch 17/60
# 10/10 [==============================] - 11s 1s/step - loss: 0.6541 - categorical_accuracy: 0.7272 - val_loss: 1.3698 - val_categorical_accuracy: 0.4670
# Epoch 18/60
# 10/10 [==============================] - 11s 1s/step - loss: 0.6423 - categorical_accuracy: 0.7185 - val_loss: 1.1238 - val_categorical_accuracy: 0.4853
# Epoch 19/60
# 10/10 [==============================] - 13s 1s/step - loss: 0.5932 - categorical_accuracy: 0.7491 - val_loss: 1.1827 - val_categorical_accuracy: 0.4877
# Epoch 20/60
# 10/10 [==============================] - 16s 2s/step - loss: 0.5431 - categorical_accuracy: 0.7849 - val_loss: 1.4540 - val_categorical_accuracy: 0.4727
# Epoch 21/60
# 10/10 [==============================] - 15s 2s/step - loss: 0.5264 - categorical_accuracy: 0.7806 - val_loss: 1.2972 - val_categorical_accuracy: 0.4215
# Epoch 22/60
# 10/10 [==============================] - 15s 2s/step - loss: 0.5545 - categorical_accuracy: 0.7696 - val_loss: 1.2233 - val_categorical_accuracy: 0.4380
# Epoch 23/60
# 10/10 [==============================] - 16s 2s/step - loss: 0.4740 - categorical_accuracy: 0.8143 - val_loss: 1.3119 - val_categorical_accuracy: 0.5017
# Epoch 24/60
# 10/10 [==============================] - 15s 2s/step - loss: 0.4310 - categorical_accuracy: 0.8281 - val_loss: 1.3650 - val_categorical_accuracy: 0.4635
# Epoch 25/60
# 10/10 [==============================] - 16s 2s/step - loss: 0.3898 - categorical_accuracy: 0.8516 - val_loss: 1.3419 - val_categorical_accuracy: 0.5017
# Epoch 26/60
# 10/10 [==============================] - 16s 2s/step - loss: 0.4333 - categorical_accuracy: 0.8367 - val_loss: 1.3712 - val_categorical_accuracy: 0.4919
# Epoch 27/60
# 10/10 [==============================] - 15s 2s/step - loss: 0.3557 - categorical_accuracy: 0.8733 - val_loss: 1.4315 - val_categorical_accuracy: 0.5064
# Epoch 28/60
# 10/10 [==============================] - 15s 2s/step - loss: 0.3700 - categorical_accuracy: 0.8629 - val_loss: 1.6126 - val_categorical_accuracy: 0.4754
# Epoch 29/60
# 10/10 [==============================] - 15s 2s/step - loss: 0.2663 - categorical_accuracy: 0.9042 - val_loss: 2.1189 - val_categorical_accuracy: 0.4187
# Epoch 30/60
# 10/10 [==============================] - 15s 2s/step - loss: 0.4242 - categorical_accuracy: 0.8232 - val_loss: 1.3675 - val_categorical_accuracy: 0.5120
# Epoch 31/60
# 10/10 [==============================] - 15s 2s/step - loss: 0.2330 - categorical_accuracy: 0.9180 - val_loss: 1.7801 - val_categorical_accuracy: 0.4427
# Epoch 32/60
# 10/10 [==============================] - 15s 1s/step - loss: 0.2582 - categorical_accuracy: 0.9045 - val_loss: 1.5882 - val_categorical_accuracy: 0.4953
# Epoch 33/60
# 10/10 [==============================] - 15s 2s/step - loss: 0.3745 - categorical_accuracy: 0.8410 - val_loss: 2.0052 - val_categorical_accuracy: 0.4818
# Epoch 34/60
# 10/10 [==============================] - 15s 1s/step - loss: 0.1730 - categorical_accuracy: 0.9480 - val_loss: 1.6763 - val_categorical_accuracy: 0.5121
# Epoch 35/60
# 10/10 [==============================] - 15s 2s/step - loss: 0.2566 - categorical_accuracy: 0.9014 - val_loss: 1.6628 - val_categorical_accuracy: 0.5128
# Epoch 36/60
# 10/10 [==============================] - 15s 2s/step - loss: 0.2168 - categorical_accuracy: 0.9266 - val_loss: 2.6638 - val_categorical_accuracy: 0.4598
# Epoch 37/60
# 10/10 [==============================] - 15s 1s/step - loss: 0.2110 - categorical_accuracy: 0.9261 - val_loss: 1.6869 - val_categorical_accuracy: 0.5131
# Epoch 38/60
# 10/10 [==============================] - 15s 2s/step - loss: 0.2633 - categorical_accuracy: 0.8822 - val_loss: 1.5529 - val_categorical_accuracy: 0.4340
# Epoch 39/60
# 10/10 [==============================] - 15s 2s/step - loss: 0.1499 - categorical_accuracy: 0.9520 - val_loss: 1.7839 - val_categorical_accuracy: 0.5138
# Epoch 40/60
# 10/10 [==============================] - 15s 2s/step - loss: 0.1944 - categorical_accuracy: 0.9266 - val_loss: 3.3880 - val_categorical_accuracy: 0.3883
# Epoch 41/60
# 10/10 [==============================] - 16s 2s/step - loss: 0.4387 - categorical_accuracy: 0.8697 - val_loss: 1.6200 - val_categorical_accuracy: 0.5140
# Epoch 42/60
# 10/10 [==============================] - 16s 2s/step - loss: 0.0905 - categorical_accuracy: 0.9733 - val_loss: 1.8487 - val_categorical_accuracy: 0.5141
# Epoch 43/60
# 10/10 [==============================] - 15s 2s/step - loss: 0.0936 - categorical_accuracy: 0.9646 - val_loss: 2.0389 - val_categorical_accuracy: 0.4850
# Epoch 44/60
# 10/10 [==============================] - 15s 2s/step - loss: 0.7450 - categorical_accuracy: 0.7817 - val_loss: 1.5363 - val_categorical_accuracy: 0.5094
# Epoch 45/60
# 10/10 [==============================] - 15s 1s/step - loss: 0.0910 - categorical_accuracy: 0.9747 - val_loss: 1.7851 - val_categorical_accuracy: 0.5165
# Epoch 46/60
# 10/10 [==============================] - 15s 1s/step - loss: 0.0731 - categorical_accuracy: 0.9762 - val_loss: 2.0453 - val_categorical_accuracy: 0.5118
# Epoch 47/60
# 10/10 [==============================] - 15s 2s/step - loss: 0.0806 - categorical_accuracy: 0.9701 - val_loss: 2.0682 - val_categorical_accuracy: 0.5083
# Epoch 48/60
# 10/10 [==============================] - 16s 2s/step - loss: 0.3344 - categorical_accuracy: 0.9104 - val_loss: 1.5260 - val_categorical_accuracy: 0.5118
# Epoch 49/60
# 10/10 [==============================] - 15s 2s/step - loss: 0.0857 - categorical_accuracy: 0.9753 - val_loss: 1.9252 - val_categorical_accuracy: 0.4938
# Epoch 50/60
# 10/10 [==============================] - 15s 2s/step - loss: 0.0711 - categorical_accuracy: 0.9750 - val_loss: 2.0992 - val_categorical_accuracy: 0.5130
# Epoch 51/60
# 10/10 [==============================] - 15s 2s/step - loss: 1.0016 - categorical_accuracy: 0.8112 - val_loss: 1.7096 - val_categorical_accuracy: 0.4889
# Epoch 52/60
# 10/10 [==============================] - 15s 1s/step - loss: 0.0813 - categorical_accuracy: 0.9764 - val_loss: 1.8370 - val_categorical_accuracy: 0.5116
# Epoch 53/60
# 10/10 [==============================] - 15s 2s/step - loss: 0.0623 - categorical_accuracy: 0.9774 - val_loss: 1.9951 - val_categorical_accuracy: 0.5128
# Epoch 54/60
# 10/10 [==============================] - 11s 1s/step - loss: 0.0545 - categorical_accuracy: 0.9800 - val_loss: 2.1721 - val_categorical_accuracy: 0.5106
# Epoch 55/60
# 10/10 [==============================] - 10s 1s/step - loss: 0.0539 - categorical_accuracy: 0.9773 - val_loss: 2.5435 - val_categorical_accuracy: 0.5029
# Epoch 56/60
# 10/10 [==============================] - 11s 1s/step - loss: 0.7689 - categorical_accuracy: 0.8055 - val_loss: 1.7138 - val_categorical_accuracy: 0.5111
# Epoch 57/60
# 10/10 [==============================] - 11s 1s/step - loss: 0.0637 - categorical_accuracy: 0.9801 - val_loss: 1.9171 - val_categorical_accuracy: 0.5163
# Epoch 58/60
# 10/10 [==============================] - 11s 1s/step - loss: 0.0525 - categorical_accuracy: 0.9801 - val_loss: 2.0784 - val_categorical_accuracy: 0.5113
# Epoch 59/60
# 10/10 [==============================] - 11s 1s/step - loss: 0.0480 - categorical_accuracy: 0.9790 - val_loss: 2.2107 - val_categorical_accuracy: 0.5116
# Epoch 60/60
# 10/10 [==============================] - 11s 1s/step - loss: 0.3565 - categorical_accuracy: 0.9047 - val_loss: 1.6692 - val_categorical_accuracy: 0.5200

# %%
# 모델의 예측값을 튜플로 반환하는 함수
def predict(x):
    data = np.expand_dims(np.asarray(x).astype('float32'),axis=0)
    result = model.predict(data)
    return tuple(result[0])

# %%
# 모든 날짜의 예측값들을 합치기 위한 튜플의 합 함수
def sum_tuple(a,b):
    return (a[0]+b[0],a[1]+b[1],a[2]+b[2])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

fig, acc_ax = plt.subplots()

loss_ax = acc_ax.twinx()

loss_ax.plot(hist.history['loss'], 'y', label='train loss')
loss_ax.plot(hist.history['val_loss'], 'r', label='val loss')

acc_ax.plot(hist.history['categorical_accuracy'], 'b', label='train acc')
acc_ax.plot(hist.history['val_categorical_accuracy'], 'g', label='val acc')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuray')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()

# %%
# Test set에 대한 예측 및 예측 정확도의 계산
import re

count = 0
sum_dic = {}
for data in train2_x:
    result = predict(data[0])
    if data[1] in sum_dic:
        sum_dic[data[1]] = sum_tuple(sum_dic[data[1]],result)
    else:
        sum_dic[data[1]] = result
    
for date in sum_dic:
    real = train2_y[date]
    value = sum_dic[date].index(max(sum_dic[date]))
    value -= 1
    if real == value:
        count = count + 1
train_score = count / len(sum_dic)

count = 0
sum_dic = {}
for data in test2_x:
    result = predict(data[0])
    if data[1] in sum_dic:
        sum_dic[data[1]] = sum_tuple(sum_dic[data[1]],result)
    else:
        sum_dic[data[1]] = result
    
for date in sum_dic:
    real = test2_y[date]
    value = sum_dic[date].index(max(sum_dic[date]))
    value -= 1
    if real == value:
        count = count + 1
test_score = count / len(sum_dic)

# %%
print('단어 갯수 : '+num_word)
print('모델 레이어 및 노드 수 : ','첫 번째 레이어 - relu,',first_layer,', 두 번째 레이어 - relu,',second_layer)
print('epochs : ',ep,', batch_size : ', ba)
print('train 데이터 정확도 : ', train_score)
print('test 데이터 정확도 : ', test_score)
# Out:
# 단어 갯수 : 6000
# 모델 레이어 및 노드 수 :  첫 번째 레이어 - relu, 3000 , 두 번째 레이어 - relu, 1000
# epochs :  60 , batch_size :  1000
# train 데이터 정확도 :  1.0
# test 데이터 정확도 :  0.788235294117647
