# %%
# 사용할 데이터의 형태
data_type = '19'      # '1' : summarize X,개별 기사   '2' : summarize X,날짜별 기사
                    # '3' : summarize O,개별 기사   '4' : summarize O,날짜별 기사
normalized = 'done' # 'done' : 데이터 행별 normalize한 데이터     'not' : 데이터 행별 normalize 안한 데이터
erased_word = ''    # 제거된 단어 형태
num_word = '6000'   # 사용할 단어 수

# 돌려볼 모델의 구조
first_layer = 3000   # 모델의 첫 번째 레이어 수
second_layer = 1000  # 모델의 두 번째 레이어 수
ep = 60             # 모델의 에포크 수
ba = 1024            # 모델의 배치 사이즈

# %%
# 생성된 training, test의 x,y값을 pickle의 형태로 저장
import pickle
import os
path = os.getcwd()+'/pickles/'
if erased_word != '':
    erased_word = '_'+erased_word
with open(path+data_type+'train_x_'+str(num_word)+'_'+normalized+erased_word+'.pickle', 'rb') as f:
    train_x = pickle.load(f)
with open(path+data_type+'train_y_'+str(num_word)+'_'+normalized+erased_word+'.pickle', 'rb') as f:
    train_y = pickle.load(f)
with open(path+data_type+'train2_x_'+str(num_word)+'_'+normalized+erased_word+'.pickle', 'rb') as f:
    train2_x = pickle.load(f)
with open(path+data_type+'train2_y_'+str(num_word)+'_'+normalized+erased_word+'.pickle', 'rb') as f:
    train2_y = pickle.load(f)
with open(path+data_type+'test_x_'+str(num_word)+'_'+normalized+erased_word+'.pickle', 'rb') as f:
    test_x = pickle.load(f)
with open(path+data_type+'test_y_'+str(num_word)+'_'+normalized+erased_word+'.pickle', 'rb') as f:
    test_y = pickle.load(f)
with open(path+data_type+'test2_x_'+str(num_word)+'_'+normalized+erased_word+'.pickle', 'rb') as f:
    test2_x = pickle.load(f)
with open(path+data_type+'test2_y_'+str(num_word)+'_'+normalized+erased_word+'.pickle', 'rb') as f:
    test2_y = pickle.load(f)

# %%
# numpy 사용하여 float로 바꾸어주는 과정
import numpy as np
x_train = np.asarray(train_x).astype('float32')
y_train = np.asarray(train_y).astype('float32')
x_test = np.asarray(test_x).astype('float32')
y_test = np.asarray(test_y).astype('float32')

# %%
# DNN 학습 모델
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import optimizers
from tensorflow.keras import losses
from tensorflow.keras import metrics
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.callbacks import ModelCheckpoint


callbacks = [ModelCheckpoint(filepath='bestModel19-2',monitor='val_categorical_accuracy',save_best_only=True)]
model = models.Sequential()
n =len(x_train[0])
model.add(layers.Dense(first_layer,activation='relu'))#실제 쓸 단어갯수

model.add(layers.Dense(second_layer,activation='relu'))

model.add(layers.Dense(3,activation='softmax'))
model.compile(optimizer=optimizers.RMSprop(lr=0.001),loss = losses.categorical_crossentropy,metrics=[metrics.categorical_accuracy])

hist = model.fit(x_train,y_train,epochs=ep,validation_data=(x_test,y_test),callbacks=callbacks,batch_size=ba)
#hist = model.fit(x_train,y_train,epochs=ep,validation_data=(x_test,y_test),batch_size=ba)
# Out:
# Epoch 1/60
# 9/9 [==============================] - ETA: 0s - loss: 1.0960 - categorical_accuracy: 0.3723INFO:tensorflow:Assets written to: bestModel19-2\assets
# 9/9 [==============================] - 6s 642ms/step - loss: 1.0960 - categorical_accuracy: 0.3723 - val_loss: 1.0864 - val_categorical_accuracy: 0.3961
# Epoch 2/60
# 9/9 [==============================] - ETA: 0s - loss: 1.0859 - categorical_accuracy: 0.3924INFO:tensorflow:Assets written to: bestModel19-2\assets
# 9/9 [==============================] - 6s 652ms/step - loss: 1.0859 - categorical_accuracy: 0.3924 - val_loss: 1.0738 - val_categorical_accuracy: 0.4229
# Epoch 3/60
# 9/9 [==============================] - ETA: 0s - loss: 1.0509 - categorical_accuracy: 0.4489INFO:tensorflow:Assets written to: bestModel19-2\assets
# 9/9 [==============================] - 6s 624ms/step - loss: 1.0509 - categorical_accuracy: 0.4489 - val_loss: 1.0612 - val_categorical_accuracy: 0.4409
# Epoch 4/60
# 9/9 [==============================] - 4s 472ms/step - loss: 1.0109 - categorical_accuracy: 0.4958 - val_loss: 1.0960 - val_categorical_accuracy: 0.4014
# Epoch 5/60
# 9/9 [==============================] - ETA: 0s - loss: 0.9737 - categorical_accuracy: 0.5320INFO:tensorflow:Assets written to: bestModel19-2\assets
# 9/9 [==============================] - 5s 594ms/step - loss: 0.9737 - categorical_accuracy: 0.5320 - val_loss: 1.0960 - val_categorical_accuracy: 0.4552
# Epoch 6/60
# 9/9 [==============================] - 4s 488ms/step - loss: 0.9520 - categorical_accuracy: 0.5459 - val_loss: 1.1209 - val_categorical_accuracy: 0.3889
# Epoch 7/60
# 9/9 [==============================] - ETA: 0s - loss: 0.9078 - categorical_accuracy: 0.5654INFO:tensorflow:Assets written to: bestModel19-2\assets
# 9/9 [==============================] - 7s 770ms/step - loss: 0.9078 - categorical_accuracy: 0.5654 - val_loss: 1.0549 - val_categorical_accuracy: 0.4785
# Epoch 8/60
# 9/9 [==============================] - 5s 512ms/step - loss: 0.8590 - categorical_accuracy: 0.6050 - val_loss: 1.0764 - val_categorical_accuracy: 0.4391
# Epoch 9/60
# 9/9 [==============================] - 5s 505ms/step - loss: 0.8327 - categorical_accuracy: 0.6130 - val_loss: 1.1007 - val_categorical_accuracy: 0.4211
# Epoch 10/60
# 9/9 [==============================] - 4s 477ms/step - loss: 0.7815 - categorical_accuracy: 0.6549 - val_loss: 1.1821 - val_categorical_accuracy: 0.4355
# Epoch 11/60
# 9/9 [==============================] - ETA: 0s - loss: 0.7756 - categorical_accuracy: 0.6497INFO:tensorflow:Assets written to: bestModel19-2\assets
# 9/9 [==============================] - 6s 642ms/step - loss: 0.7756 - categorical_accuracy: 0.6497 - val_loss: 1.0598 - val_categorical_accuracy: 0.4964
# Epoch 12/60
# 9/9 [==============================] - ETA: 0s - loss: 0.7454 - categorical_accuracy: 0.6660INFO:tensorflow:Assets written to: bestModel19-2\assets
# 9/9 [==============================] - 6s 688ms/step - loss: 0.7454 - categorical_accuracy: 0.6660 - val_loss: 1.0664 - val_categorical_accuracy: 0.5179
# Epoch 13/60
# 9/9 [==============================] - 4s 491ms/step - loss: 0.7227 - categorical_accuracy: 0.6747 - val_loss: 1.1032 - val_categorical_accuracy: 0.4821
# Epoch 14/60
# 9/9 [==============================] - 4s 496ms/step - loss: 0.6799 - categorical_accuracy: 0.7099 - val_loss: 1.2125 - val_categorical_accuracy: 0.4695
# Epoch 15/60
# 9/9 [==============================] - 4s 475ms/step - loss: 0.6708 - categorical_accuracy: 0.7183 - val_loss: 1.0808 - val_categorical_accuracy: 0.5179
# Epoch 16/60
# 9/9 [==============================] - 4s 471ms/step - loss: 0.5954 - categorical_accuracy: 0.7517 - val_loss: 1.3090 - val_categorical_accuracy: 0.4444
# Epoch 17/60
# 9/9 [==============================] - 4s 473ms/step - loss: 0.6136 - categorical_accuracy: 0.7327 - val_loss: 1.2518 - val_categorical_accuracy: 0.4695
# Epoch 18/60
# 9/9 [==============================] - 4s 472ms/step - loss: 0.5655 - categorical_accuracy: 0.7607 - val_loss: 1.3504 - val_categorical_accuracy: 0.4982
# Epoch 19/60
# 9/9 [==============================] - ETA: 0s - loss: 0.5904 - categorical_accuracy: 0.7562INFO:tensorflow:Assets written to: bestModel19-2\assets
# 9/9 [==============================] - 5s 587ms/step - loss: 0.5904 - categorical_accuracy: 0.7562 - val_loss: 1.0839 - val_categorical_accuracy: 0.5573
# Epoch 20/60
# 9/9 [==============================] - 4s 482ms/step - loss: 0.5289 - categorical_accuracy: 0.7812 - val_loss: 1.2116 - val_categorical_accuracy: 0.4982
# Epoch 21/60
# 9/9 [==============================] - ETA: 0s - loss: 0.4547 - categorical_accuracy: 0.8199INFO:tensorflow:Assets written to: bestModel19-2\assets
# 9/9 [==============================] - 6s 699ms/step - loss: 0.4547 - categorical_accuracy: 0.8199 - val_loss: 1.0866 - val_categorical_accuracy: 0.5717
# Epoch 22/60
# 9/9 [==============================] - ETA: 0s - loss: 0.5027 - categorical_accuracy: 0.7979INFO:tensorflow:Assets written to: bestModel19-2\assets
# 9/9 [==============================] - 6s 672ms/step - loss: 0.5027 - categorical_accuracy: 0.7979 - val_loss: 1.1149 - val_categorical_accuracy: 0.5735
# Epoch 23/60
# 9/9 [==============================] - 4s 461ms/step - loss: 0.4614 - categorical_accuracy: 0.8121 - val_loss: 1.1814 - val_categorical_accuracy: 0.5663
# Epoch 24/60
# 9/9 [==============================] - ETA: 0s - loss: 0.4308 - categorical_accuracy: 0.8232INFO:tensorflow:Assets written to: bestModel19-2\assets
# 9/9 [==============================] - 5s 577ms/step - loss: 0.4308 - categorical_accuracy: 0.8232 - val_loss: 1.1280 - val_categorical_accuracy: 0.5950
# Epoch 25/60
# 9/9 [==============================] - ETA: 0s - loss: 0.4626 - categorical_accuracy: 0.8103INFO:tensorflow:Assets written to: bestModel19-2\assets
# 9/9 [==============================] - 6s 667ms/step - loss: 0.4626 - categorical_accuracy: 0.8103 - val_loss: 1.0715 - val_categorical_accuracy: 0.5968
# Epoch 26/60
# 9/9 [==============================] - 4s 477ms/step - loss: 0.4023 - categorical_accuracy: 0.8555 - val_loss: 1.3192 - val_categorical_accuracy: 0.4946
# Epoch 27/60
# 9/9 [==============================] - 4s 471ms/step - loss: 0.2718 - categorical_accuracy: 0.9220 - val_loss: 1.4327 - val_categorical_accuracy: 0.5609
# Epoch 28/60
# 9/9 [==============================] - 4s 476ms/step - loss: 0.4128 - categorical_accuracy: 0.8302 - val_loss: 1.1749 - val_categorical_accuracy: 0.5609
# Epoch 29/60
# 9/9 [==============================] - 4s 469ms/step - loss: 0.3282 - categorical_accuracy: 0.8717 - val_loss: 1.0798 - val_categorical_accuracy: 0.5968
# Epoch 30/60
# 9/9 [==============================] - ETA: 0s - loss: 0.2729 - categorical_accuracy: 0.9135INFO:tensorflow:Assets written to: bestModel19-2\assets
# 9/9 [==============================] - 6s 689ms/step - loss: 0.2729 - categorical_accuracy: 0.9135 - val_loss: 1.2793 - val_categorical_accuracy: 0.6057
# Epoch 31/60
# 9/9 [==============================] - 4s 489ms/step - loss: 0.3861 - categorical_accuracy: 0.8504 - val_loss: 1.1140 - val_categorical_accuracy: 0.5986
# Epoch 32/60
# 9/9 [==============================] - 4s 476ms/step - loss: 0.1548 - categorical_accuracy: 0.9664 - val_loss: 1.4615 - val_categorical_accuracy: 0.5681
# Epoch 33/60
# 9/9 [==============================] - 4s 472ms/step - loss: 0.3139 - categorical_accuracy: 0.8929 - val_loss: 1.5163 - val_categorical_accuracy: 0.5215
# Epoch 34/60
# 9/9 [==============================] - 4s 461ms/step - loss: 0.1889 - categorical_accuracy: 0.9373 - val_loss: 2.1007 - val_categorical_accuracy: 0.4534
# Epoch 35/60
# 9/9 [==============================] - 4s 466ms/step - loss: 0.2587 - categorical_accuracy: 0.9016 - val_loss: 1.4112 - val_categorical_accuracy: 0.5986
# Epoch 36/60
# 9/9 [==============================] - 4s 489ms/step - loss: 0.2488 - categorical_accuracy: 0.9155 - val_loss: 1.3377 - val_categorical_accuracy: 0.5036
# Epoch 37/60
# 9/9 [==============================] - 4s 471ms/step - loss: 0.1398 - categorical_accuracy: 0.9666 - val_loss: 1.5290 - val_categorical_accuracy: 0.5896
# Epoch 38/60
# 9/9 [==============================] - 5s 508ms/step - loss: 0.2681 - categorical_accuracy: 0.9111 - val_loss: 1.2957 - val_categorical_accuracy: 0.6004
# Epoch 39/60
# 9/9 [==============================] - 4s 494ms/step - loss: 0.0775 - categorical_accuracy: 0.9874 - val_loss: 1.6725 - val_categorical_accuracy: 0.5968
# Epoch 40/60
# 9/9 [==============================] - 4s 476ms/step - loss: 0.4448 - categorical_accuracy: 0.8799 - val_loss: 1.2952 - val_categorical_accuracy: 0.5986
# Epoch 41/60
# 9/9 [==============================] - 4s 467ms/step - loss: 0.0714 - categorical_accuracy: 0.9895 - val_loss: 1.5893 - val_categorical_accuracy: 0.5878
# Epoch 42/60
# 9/9 [==============================] - 4s 485ms/step - loss: 0.3183 - categorical_accuracy: 0.8975 - val_loss: 2.1475 - val_categorical_accuracy: 0.4910
# Epoch 43/60
# 9/9 [==============================] - 4s 498ms/step - loss: 0.1726 - categorical_accuracy: 0.9562 - val_loss: 1.5016 - val_categorical_accuracy: 0.5968
# Epoch 44/60
# 9/9 [==============================] - 5s 534ms/step - loss: 0.0498 - categorical_accuracy: 0.9911 - val_loss: 1.6850 - val_categorical_accuracy: 0.5896
# Epoch 45/60
# 9/9 [==============================] - 5s 503ms/step - loss: 0.2515 - categorical_accuracy: 0.9175 - val_loss: 1.2240 - val_categorical_accuracy: 0.5968
# Epoch 46/60
# 9/9 [==============================] - 4s 460ms/step - loss: 0.0685 - categorical_accuracy: 0.9915 - val_loss: 1.6880 - val_categorical_accuracy: 0.5950
# Epoch 47/60
# 9/9 [==============================] - ETA: 0s - loss: 0.2434 - categorical_accuracy: 0.9226INFO:tensorflow:Assets written to: bestModel19-2\assets
# 9/9 [==============================] - 7s 723ms/step - loss: 0.2434 - categorical_accuracy: 0.9226 - val_loss: 1.2824 - val_categorical_accuracy: 0.6147
# Epoch 48/60
# 9/9 [==============================] - 4s 484ms/step - loss: 0.0492 - categorical_accuracy: 0.9922 - val_loss: 1.6697 - val_categorical_accuracy: 0.5878
# Epoch 49/60
# 9/9 [==============================] - 5s 518ms/step - loss: 0.1339 - categorical_accuracy: 0.9566 - val_loss: 2.9719 - val_categorical_accuracy: 0.5143
# Epoch 50/60
# 9/9 [==============================] - 4s 489ms/step - loss: 0.2207 - categorical_accuracy: 0.9566 - val_loss: 1.5064 - val_categorical_accuracy: 0.6057
# Epoch 51/60
# 9/9 [==============================] - 4s 482ms/step - loss: 0.0336 - categorical_accuracy: 0.9930 - val_loss: 1.7412 - val_categorical_accuracy: 0.6129
# Epoch 52/60
# 9/9 [==============================] - 5s 522ms/step - loss: 0.0418 - categorical_accuracy: 0.9887 - val_loss: 3.8021 - val_categorical_accuracy: 0.4534
# Epoch 53/60
# 9/9 [==============================] - 5s 520ms/step - loss: 0.3308 - categorical_accuracy: 0.9216 - val_loss: 1.5331 - val_categorical_accuracy: 0.6004
# Epoch 54/60
# 9/9 [==============================] - 5s 505ms/step - loss: 0.0294 - categorical_accuracy: 0.9942 - val_loss: 1.7492 - val_categorical_accuracy: 0.6111
# Epoch 55/60
# 9/9 [==============================] - 5s 501ms/step - loss: 0.0431 - categorical_accuracy: 0.9873 - val_loss: 4.9452 - val_categorical_accuracy: 0.2957
# Epoch 56/60
# 9/9 [==============================] - 5s 508ms/step - loss: 0.7919 - categorical_accuracy: 0.8220 - val_loss: 1.4985 - val_categorical_accuracy: 0.5986
# Epoch 57/60
# 9/9 [==============================] - 5s 508ms/step - loss: 0.0310 - categorical_accuracy: 0.9950 - val_loss: 1.6717 - val_categorical_accuracy: 0.6039
# Epoch 58/60
# 9/9 [==============================] - 5s 526ms/step - loss: 0.0226 - categorical_accuracy: 0.9943 - val_loss: 1.8065 - val_categorical_accuracy: 0.6039
# Epoch 59/60
# 9/9 [==============================] - 4s 496ms/step - loss: 0.0196 - categorical_accuracy: 0.9941 - val_loss: 1.9547 - val_categorical_accuracy: 0.5950
# Epoch 60/60
# 9/9 [==============================] - 4s 482ms/step - loss: 0.0528 - categorical_accuracy: 0.9828 - val_loss: 4.6055 - val_categorical_accuracy: 0.3961

# %%
# 모델의 예측값을 튜플로 반환하는 함수
def predict(x):
    data = np.expand_dims(np.asarray(x).astype('float32'),axis=0)
    result = model.predict(data)
    return tuple(result[0])

# %%
# 모든 날짜의 예측값들을 합치기 위한 튜플의 합 함수
def sum_tuple(a,b):
    return (a[0]+b[0],a[1]+b[1],a[2]+b[2])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

fig, acc_ax = plt.subplots()

loss_ax = acc_ax.twinx()

loss_ax.plot(hist.history['loss'], 'y', label='train loss')
loss_ax.plot(hist.history['val_loss'], 'r', label='val loss')

acc_ax.plot(hist.history['categorical_accuracy'], 'b', label='train acc')
acc_ax.plot(hist.history['val_categorical_accuracy'], 'g', label='val acc')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuray')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()

# %%
# Test set에 대한 예측 및 예측 정확도의 계산
import re

count = 0
sum_dic = {}
for data in train2_x:
    result = predict(data[0])
    if data[1] in sum_dic:
        sum_dic[data[1]] = sum_tuple(sum_dic[data[1]],result)
    else:
        sum_dic[data[1]] = result
    
for date in sum_dic:
    real = train2_y[date]
    value = sum_dic[date].index(max(sum_dic[date]))
    value -= 1
    if real == value:
        count = count + 1
train_score = count / len(sum_dic)

count = 0
sum_dic = {}
for data in test2_x:
    result = predict(data[0])
    if data[1] in sum_dic:
        sum_dic[data[1]] = sum_tuple(sum_dic[data[1]],result)
    else:
        sum_dic[data[1]] = result
    
for date in sum_dic:
    real = test2_y[date]
    value = sum_dic[date].index(max(sum_dic[date]))
    value -= 1
    if real == value:
        count = count + 1
test_score = count / len(sum_dic)

# %%
print('단어 갯수 : '+num_word)
print('모델 레이어 및 노드 수 : ','첫 번째 레이어 - relu,',first_layer,', 두 번째 레이어 - relu,',second_layer)
print('epochs : ',ep,', batch_size : ', ba)
print('train 데이터 정확도 : ', train_score)
print('test 데이터 정확도 : ', test_score)
