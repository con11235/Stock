# %%
# 사용할 데이터의 형태
data_type = '17'      # '1' : summarize X,개별 기사   '2' : summarize X,날짜별 기사
                    # '3' : summarize O,개별 기사   '4' : summarize O,날짜별 기사
normalized = 'done' # 'done' : 데이터 행별 normalize한 데이터     'not' : 데이터 행별 normalize 안한 데이터
erased_word = ''    # 제거된 단어 형태
num_word = '6000'   # 사용할 단어 수

# 돌려볼 모델의 구조
first_layer = 3000   # 모델의 첫 번째 레이어 수
second_layer = 1000  # 모델의 두 번째 레이어 수
ep = 60             # 모델의 에포크 수
ba = 1024            # 모델의 배치 사이즈

# %%
# 생성된 training, test의 x,y값을 pickle의 형태로 저장
import pickle
import os
path = os.getcwd()+'/pickles/'
if erased_word != '':
    erased_word = '_'+erased_word
with open(path+data_type+'train_x_'+str(num_word)+'_'+normalized+erased_word+'.pickle', 'rb') as f:
    train_x = pickle.load(f)
with open(path+data_type+'train_y_'+str(num_word)+'_'+normalized+erased_word+'.pickle', 'rb') as f:
    train_y = pickle.load(f)
with open(path+data_type+'train2_x_'+str(num_word)+'_'+normalized+erased_word+'.pickle', 'rb') as f:
    train2_x = pickle.load(f)
with open(path+data_type+'train2_y_'+str(num_word)+'_'+normalized+erased_word+'.pickle', 'rb') as f:
    train2_y = pickle.load(f)
with open(path+data_type+'test_x_'+str(num_word)+'_'+normalized+erased_word+'.pickle', 'rb') as f:
    test_x = pickle.load(f)
with open(path+data_type+'test_y_'+str(num_word)+'_'+normalized+erased_word+'.pickle', 'rb') as f:
    test_y = pickle.load(f)
with open(path+data_type+'test2_x_'+str(num_word)+'_'+normalized+erased_word+'.pickle', 'rb') as f:
    test2_x = pickle.load(f)
with open(path+data_type+'test2_y_'+str(num_word)+'_'+normalized+erased_word+'.pickle', 'rb') as f:
    test2_y = pickle.load(f)

# %%
# numpy 사용하여 float로 바꾸어주는 과정
import numpy as np
x_train = np.asarray(train_x).astype('float32')
y_train = np.asarray(train_y).astype('float32')
x_test = np.asarray(test_x).astype('float32')
y_test = np.asarray(test_y).astype('float32')

# %%
# DNN 학습 모델
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import optimizers
from tensorflow.keras import losses
from tensorflow.keras import metrics
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.callbacks import ModelCheckpoint


callbacks = [ModelCheckpoint(filepath='bestModel',monitor='val_categorical_accuracy',save_best_only=True)]
model = models.Sequential()
n =len(x_train[0])
model.add(layers.Dense(first_layer,activation='relu'))#실제 쓸 단어갯수

model.add(layers.Dense(second_layer,activation='relu'))

model.add(layers.Dense(3,activation='softmax'))
model.compile(optimizer=optimizers.RMSprop(lr=0.001),loss = losses.categorical_crossentropy,metrics=[metrics.categorical_accuracy])

hist = model.fit(x_train,y_train,epochs=ep,validation_data=(x_test,y_test),callbacks=callbacks,batch_size=ba)
#hist = model.fit(x_train,y_train,epochs=ep,validation_data=(x_test,y_test),batch_size=ba)

# 모델의 예측값을 튜플로 반환하는 함수
def predict(x):
    data = np.expand_dims(np.asarray(x).astype('float32'),axis=0)
    result = model.predict(data)
    return tuple(result[0])
# Out:
# Epoch 1/60
# 5/5 [==============================] - ETA: 0s - loss: 1.0978 - categorical_accuracy: 0.3561INFO:tensorflow:Assets written to: bestModel/assets
# 5/5 [==============================] - 3s 506ms/step - loss: 1.0978 - categorical_accuracy: 0.3561 - val_loss: 1.0929 - val_categorical_accuracy: 0.3835
# Epoch 2/60
# 5/5 [==============================] - ETA: 0s - loss: 1.0890 - categorical_accuracy: 0.3843INFO:tensorflow:Assets written to: bestModel/assets
# 5/5 [==============================] - 3s 510ms/step - loss: 1.0890 - categorical_accuracy: 0.3843 - val_loss: 1.0851 - val_categorical_accuracy: 0.3889
# Epoch 3/60
# 5/5 [==============================] - ETA: 0s - loss: 1.0731 - categorical_accuracy: 0.3798INFO:tensorflow:Assets written to: bestModel/assets
# 5/5 [==============================] - 2s 488ms/step - loss: 1.0731 - categorical_accuracy: 0.3798 - val_loss: 1.0720 - val_categorical_accuracy: 0.4283
# Epoch 4/60
# 5/5 [==============================] - ETA: 0s - loss: 1.0924 - categorical_accuracy: 0.3966INFO:tensorflow:Assets written to: bestModel/assets
# 5/5 [==============================] - 3s 518ms/step - loss: 1.0924 - categorical_accuracy: 0.3966 - val_loss: 1.0643 - val_categorical_accuracy: 0.4498
# Epoch 5/60
# 5/5 [==============================] - 2s 331ms/step - loss: 1.0331 - categorical_accuracy: 0.4368 - val_loss: 1.0529 - val_categorical_accuracy: 0.4409
# Epoch 6/60
# 5/5 [==============================] - 2s 376ms/step - loss: 1.0010 - categorical_accuracy: 0.4899 - val_loss: 1.1206 - val_categorical_accuracy: 0.3315
# Epoch 7/60
# 5/5 [==============================] - ETA: 0s - loss: 0.9884 - categorical_accuracy: 0.5183INFO:tensorflow:Assets written to: bestModel/assets
# 5/5 [==============================] - 3s 594ms/step - loss: 0.9884 - categorical_accuracy: 0.5183 - val_loss: 1.0500 - val_categorical_accuracy: 0.4785
# Epoch 8/60
# 5/5 [==============================] - 2s 334ms/step - loss: 0.9746 - categorical_accuracy: 0.5487 - val_loss: 1.1365 - val_categorical_accuracy: 0.3799
# Epoch 9/60
# 5/5 [==============================] - 2s 384ms/step - loss: 0.9184 - categorical_accuracy: 0.5856 - val_loss: 1.0507 - val_categorical_accuracy: 0.4391
# Epoch 10/60
# 5/5 [==============================] - ETA: 0s - loss: 0.9242 - categorical_accuracy: 0.5643INFO:tensorflow:Assets written to: bestModel/assets
# 5/5 [==============================] - 3s 541ms/step - loss: 0.9242 - categorical_accuracy: 0.5643 - val_loss: 1.0106 - val_categorical_accuracy: 0.5000
# Epoch 11/60
# 5/5 [==============================] - 2s 326ms/step - loss: 0.8149 - categorical_accuracy: 0.6687 - val_loss: 1.1176 - val_categorical_accuracy: 0.4444
# Epoch 12/60
# 5/5 [==============================] - 2s 344ms/step - loss: 0.8998 - categorical_accuracy: 0.5914 - val_loss: 1.0455 - val_categorical_accuracy: 0.4964
# Epoch 13/60
# 5/5 [==============================] - 2s 345ms/step - loss: 0.7743 - categorical_accuracy: 0.6825 - val_loss: 1.2674 - val_categorical_accuracy: 0.3746
# Epoch 14/60
# 5/5 [==============================] - 2s 337ms/step - loss: 0.7971 - categorical_accuracy: 0.6479 - val_loss: 1.0684 - val_categorical_accuracy: 0.4695
# Epoch 15/60
# 5/5 [==============================] - 2s 340ms/step - loss: 0.7619 - categorical_accuracy: 0.6577 - val_loss: 1.1038 - val_categorical_accuracy: 0.4677
# Epoch 16/60
# 5/5 [==============================] - 2s 337ms/step - loss: 0.7318 - categorical_accuracy: 0.6821 - val_loss: 1.0426 - val_categorical_accuracy: 0.4964
# Epoch 17/60
# 5/5 [==============================] - 2s 348ms/step - loss: 0.6838 - categorical_accuracy: 0.7049 - val_loss: 1.1022 - val_categorical_accuracy: 0.4480
# Epoch 18/60
# 5/5 [==============================] - ETA: 0s - loss: 0.6829 - categorical_accuracy: 0.7109INFO:tensorflow:Assets written to: bestModel/assets
# 5/5 [==============================] - 3s 534ms/step - loss: 0.6829 - categorical_accuracy: 0.7109 - val_loss: 1.0570 - val_categorical_accuracy: 0.5108
# Epoch 19/60
# 5/5 [==============================] - 2s 340ms/step - loss: 0.6931 - categorical_accuracy: 0.6883 - val_loss: 1.0603 - val_categorical_accuracy: 0.5018
# Epoch 20/60
# 5/5 [==============================] - ETA: 0s - loss: 0.6235 - categorical_accuracy: 0.7402INFO:tensorflow:Assets written to: bestModel/assets
# 5/5 [==============================] - 3s 530ms/step - loss: 0.6235 - categorical_accuracy: 0.7402 - val_loss: 1.0639 - val_categorical_accuracy: 0.5179
# Epoch 21/60
# 5/5 [==============================] - ETA: 0s - loss: 0.6208 - categorical_accuracy: 0.7292INFO:tensorflow:Assets written to: bestModel/assets
# 5/5 [==============================] - 2s 499ms/step - loss: 0.6208 - categorical_accuracy: 0.7292 - val_loss: 0.9783 - val_categorical_accuracy: 0.5591
# Epoch 22/60
# 5/5 [==============================] - 2s 339ms/step - loss: 0.5436 - categorical_accuracy: 0.7918 - val_loss: 1.1021 - val_categorical_accuracy: 0.5018
# Epoch 23/60
# 5/5 [==============================] - 2s 365ms/step - loss: 0.5288 - categorical_accuracy: 0.7933 - val_loss: 1.2483 - val_categorical_accuracy: 0.4677
# Epoch 24/60
# 5/5 [==============================] - 2s 384ms/step - loss: 0.4923 - categorical_accuracy: 0.8262 - val_loss: 1.2032 - val_categorical_accuracy: 0.5323
# Epoch 25/60
# 5/5 [==============================] - 2s 453ms/step - loss: 0.5679 - categorical_accuracy: 0.7531 - val_loss: 1.0485 - val_categorical_accuracy: 0.5466
# Epoch 26/60
# 5/5 [==============================] - ETA: 0s - loss: 0.5937 - categorical_accuracy: 0.7491INFO:tensorflow:Assets written to: bestModel/assets
# 5/5 [==============================] - 3s 571ms/step - loss: 0.5937 - categorical_accuracy: 0.7491 - val_loss: 1.0120 - val_categorical_accuracy: 0.5627
# Epoch 27/60
# 5/5 [==============================] - 2s 354ms/step - loss: 0.4307 - categorical_accuracy: 0.8362 - val_loss: 1.0660 - val_categorical_accuracy: 0.5341
# Epoch 28/60
# 5/5 [==============================] - 2s 351ms/step - loss: 0.3641 - categorical_accuracy: 0.8814 - val_loss: 1.5784 - val_categorical_accuracy: 0.4229
# Epoch 29/60
# 5/5 [==============================] - ETA: 0s - loss: 0.6359 - categorical_accuracy: 0.7248INFO:tensorflow:Assets written to: bestModel/assets
# 5/5 [==============================] - 5s 1s/step - loss: 0.6359 - categorical_accuracy: 0.7248 - val_loss: 1.0571 - val_categorical_accuracy: 0.5771
# Epoch 30/60
# 5/5 [==============================] - 2s 367ms/step - loss: 0.3343 - categorical_accuracy: 0.8908 - val_loss: 1.2806 - val_categorical_accuracy: 0.4910
# Epoch 31/60
# 5/5 [==============================] - ETA: 0s - loss: 0.4066 - categorical_accuracy: 0.8400INFO:tensorflow:Assets written to: bestModel/assets
# 5/5 [==============================] - 3s 560ms/step - loss: 0.4066 - categorical_accuracy: 0.8400 - val_loss: 1.0969 - val_categorical_accuracy: 0.5914
# Epoch 32/60
# 5/5 [==============================] - 2s 374ms/step - loss: 0.3174 - categorical_accuracy: 0.8925 - val_loss: 1.4965 - val_categorical_accuracy: 0.4462
# Epoch 33/60
# 5/5 [==============================] - 2s 371ms/step - loss: 0.5191 - categorical_accuracy: 0.7857 - val_loss: 1.0962 - val_categorical_accuracy: 0.5806
# Epoch 34/60
# 5/5 [==============================] - 2s 363ms/step - loss: 0.2529 - categorical_accuracy: 0.9272 - val_loss: 1.2846 - val_categorical_accuracy: 0.5179
# Epoch 35/60
# 5/5 [==============================] - 2s 373ms/step - loss: 0.3452 - categorical_accuracy: 0.8561 - val_loss: 1.4137 - val_categorical_accuracy: 0.5125
# Epoch 36/60
# 5/5 [==============================] - ETA: 0s - loss: 0.4980 - categorical_accuracy: 0.7969INFO:tensorflow:Assets written to: bestModel/assets
# 5/5 [==============================] - 3s 538ms/step - loss: 0.4980 - categorical_accuracy: 0.7969 - val_loss: 1.0846 - val_categorical_accuracy: 0.5950
# Epoch 37/60
# 5/5 [==============================] - 2s 345ms/step - loss: 0.1914 - categorical_accuracy: 0.9544 - val_loss: 1.4319 - val_categorical_accuracy: 0.5125
# Epoch 38/60
# 5/5 [==============================] - 2s 383ms/step - loss: 0.4592 - categorical_accuracy: 0.8168 - val_loss: 1.1645 - val_categorical_accuracy: 0.5842
# Epoch 39/60
# 5/5 [==============================] - 2s 386ms/step - loss: 0.2565 - categorical_accuracy: 0.9158 - val_loss: 1.3090 - val_categorical_accuracy: 0.5842
# Epoch 40/60
# 5/5 [==============================] - 2s 373ms/step - loss: 0.2203 - categorical_accuracy: 0.9348 - val_loss: 1.2716 - val_categorical_accuracy: 0.5932
# Epoch 41/60
# 5/5 [==============================] - 2s 374ms/step - loss: 0.3024 - categorical_accuracy: 0.8749 - val_loss: 1.3103 - val_categorical_accuracy: 0.5538
# Epoch 42/60
# 5/5 [==============================] - 2s 368ms/step - loss: 0.2485 - categorical_accuracy: 0.9169 - val_loss: 1.4385 - val_categorical_accuracy: 0.5072
# Epoch 43/60
# 5/5 [==============================] - 2s 359ms/step - loss: 0.2406 - categorical_accuracy: 0.9120 - val_loss: 1.2675 - val_categorical_accuracy: 0.5950
# Epoch 44/60
# 5/5 [==============================] - 2s 358ms/step - loss: 0.2122 - categorical_accuracy: 0.9176 - val_loss: 1.7082 - val_categorical_accuracy: 0.4928
# Epoch 45/60
# 5/5 [==============================] - ETA: 0s - loss: 0.2618 - categorical_accuracy: 0.8983INFO:tensorflow:Assets written to: bestModel/assets
# 5/5 [==============================] - 3s 544ms/step - loss: 0.2618 - categorical_accuracy: 0.8983 - val_loss: 1.2840 - val_categorical_accuracy: 0.6039
# Epoch 46/60
# 5/5 [==============================] - 2s 353ms/step - loss: 0.1025 - categorical_accuracy: 0.9770 - val_loss: 1.4946 - val_categorical_accuracy: 0.5502
# Epoch 47/60
# 5/5 [==============================] - 2s 355ms/step - loss: 0.4719 - categorical_accuracy: 0.8273 - val_loss: 1.1634 - val_categorical_accuracy: 0.5986
# Epoch 48/60
# 5/5 [==============================] - 2s 347ms/step - loss: 0.1207 - categorical_accuracy: 0.9797 - val_loss: 1.3517 - val_categorical_accuracy: 0.5914
# Epoch 49/60
# 5/5 [==============================] - 2s 353ms/step - loss: 0.1045 - categorical_accuracy: 0.9750 - val_loss: 1.5508 - val_categorical_accuracy: 0.5806
# Epoch 50/60
# 5/5 [==============================] - 2s 347ms/step - loss: 0.3019 - categorical_accuracy: 0.8697 - val_loss: 1.2922 - val_categorical_accuracy: 0.5824
# Epoch 51/60
# 5/5 [==============================] - 2s 347ms/step - loss: 0.0950 - categorical_accuracy: 0.9792 - val_loss: 1.4089 - val_categorical_accuracy: 0.5950
# Epoch 52/60
# 5/5 [==============================] - 2s 346ms/step - loss: 0.0763 - categorical_accuracy: 0.9777 - val_loss: 1.7347 - val_categorical_accuracy: 0.5323
# Epoch 53/60
# 5/5 [==============================] - 2s 349ms/step - loss: 0.4168 - categorical_accuracy: 0.8423 - val_loss: 1.2782 - val_categorical_accuracy: 0.5950
# Epoch 54/60
# 5/5 [==============================] - 2s 349ms/step - loss: 0.0791 - categorical_accuracy: 0.9875 - val_loss: 1.4532 - val_categorical_accuracy: 0.5824
# Epoch 55/60
# 5/5 [==============================] - 2s 350ms/step - loss: 0.0567 - categorical_accuracy: 0.9886 - val_loss: 1.5833 - val_categorical_accuracy: 0.5824
# Epoch 56/60
# 5/5 [==============================] - 2s 340ms/step - loss: 0.1858 - categorical_accuracy: 0.9428 - val_loss: 2.4997 - val_categorical_accuracy: 0.4749
# Epoch 57/60
# 5/5 [==============================] - 2s 345ms/step - loss: 0.4253 - categorical_accuracy: 0.8336 - val_loss: 1.2918 - val_categorical_accuracy: 0.5860
# Epoch 58/60
# 5/5 [==============================] - 2s 342ms/step - loss: 0.0617 - categorical_accuracy: 0.9895 - val_loss: 1.4291 - val_categorical_accuracy: 0.5878
# Epoch 59/60
# 5/5 [==============================] - 2s 343ms/step - loss: 0.0476 - categorical_accuracy: 0.9891 - val_loss: 1.5412 - val_categorical_accuracy: 0.5878
# Epoch 60/60
# 5/5 [==============================] - 2s 371ms/step - loss: 0.0425 - categorical_accuracy: 0.9904 - val_loss: 1.6455 - val_categorical_accuracy: 0.5771

# %%
model_best = models.load_model('bestModel')

def b_predict(x):
    data = np.expand_dims(np.asarray(x).astype('float32'),axis=0)
    result = model_best.predict(data)
    return tuple(result[0])

# %%
# 모든 날짜의 예측값들을 합치기 위한 튜플의 합 함수

def sum_tuple(a,b):
    return (a[0]+b[0],a[1]+b[1],a[2]+b[2])

# %%
#8
# %matplotlib inline
import matplotlib.pyplot as plt

fig, acc_ax = plt.subplots()

loss_ax = acc_ax.twinx()

loss_ax.plot(hist.history['loss'], 'y', label='train loss')
loss_ax.plot(hist.history['val_loss'], 'r', label='val loss')

acc_ax.plot(hist.history['categorical_accuracy'], 'b', label='train acc')
acc_ax.plot(hist.history['val_categorical_accuracy'], 'g', label='val acc')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuray')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()

# %%
# Test set에 대한 예측 및 예측 정확도의 계산
#money190101을 트레이닝으로 삼은 모델로 final_maekyung190101예측결과) 0.0077 -0.005
#optimizer :RMSprop
import re
print('데이터 타입 : '+data_type)
print('단어 갯수 : '+num_word)
print('행당 노말라이즈 : '+ normalized)
print('모델 레이어 및 노드 수 : ','첫 번째 레이어 - relu,',first_layer,', 두 번째 레이어 - relu,',second_layer)
print('epochs : ',ep,', batch_size : ', ba)

count = 0
sum_dic = {}
for data in test2_x:
    result = b_predict(data[0])
    if data[1] in sum_dic:
        sum_dic[data[1]] = sum_tuple(sum_dic[data[1]],result)
    else:
        sum_dic[data[1]] = result
    
for date in sum_dic:
    real = test2_y[date]
    value = sum_dic[date].index(max(sum_dic[date]))
    value -= 1
    if real == value:
        count = count + 1
test_score = count / len(sum_dic)


#print('train 데이터 정확도 : ', train_score)
print('test 데이터 정확도 : ', test_score)
# Out:
# 데이터 타입 : 17
# 단어 갯수 : 6000
# 행당 노말라이즈 : done
# 모델 레이어 및 노드 수 :  첫 번째 레이어 - relu, 3000 , 두 번째 레이어 - relu, 1000
# epochs :  60 , batch_size :  1024
# test 데이터 정확도 :  0.7894736842105263
